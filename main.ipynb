# %%
import os, json, subprocess, re, warnings
from pathlib import Path

warnings.filterwarnings("ignore")

# Adjust if notebook is elsewhere, but this matches your current layout
FFMPEG_DIR = Path("./") / "ffmpeg-2025-12-10-git-4f947880bd-essentials_build" / "bin"
FFMPEG_BIN = str((FFMPEG_DIR / "ffmpeg.exe").resolve())
FFPROBE_BIN = str((FFMPEG_DIR / "ffprobe.exe").resolve())

print("FFMPEG_BIN =", FFMPEG_BIN)
print("FFPROBE_BIN =", FFPROBE_BIN)

# Folder with your 50 MP3s
MP3_FOLDER = Path(r"D:/Downloads/Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook").resolve()
print("MP3_FOLDER =", MP3_FOLDER)

# Final output name (base)
DEFAULT_OUTPUT_NAME = "Oh_God_Not_Again_Harry_Potter_FanFic.m4b"

METADATA = {
    "title": "Oh God Not Again! Harry Potter FanFic",
    "artist": "Sarah1281",
    "author": "Sarah1281",
    "album": "Oh God Not Again! Harry Potter FanFic Audiobook",
    "album_artist": "Patronus Pages",
    "genre": "Audiobook",
    "date": "2008",
    "comment": (
        "Patronus Pages YT audiobook: "
        "https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD "
        "based on Harry Potter FanFic: "
        "https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again"
    ),
}

def get_duration(file_path: Path) -> float:
    """Get audio duration in seconds using ffprobe."""
    cmd = [
        FFPROBE_BIN, "-v", "quiet", "-print_format", "json",
        "-show_format", str(file_path)
    ]
    result = subprocess.run(cmd, capture_output=True, text=True, check=True)
    data = json.loads(result.stdout)
    return float(data["format"]["duration"])

def parse_chapter_number(filename: str) -> int:
    """Extract chapter number from 'Chapter X' pattern in filename."""
    match = re.search(r"Chapter\s+(\d+)", filename, re.IGNORECASE)
    return int(match.group(1)) if match else float("inf")
# Out:
# FFMPEG_BIN = D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe
# FFPROBE_BIN = D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffprobe.exe
# MP3_FOLDER = D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook

# %%
#Recode mp3 and create intermediate files

folder = MP3_FOLDER
print("Using MP3 folder:", folder)

mp3_files = list(folder.glob("*.mp3"))
if not mp3_files:
    raise SystemExit("No MP3 files found in folder")

# Sort by chapter number in filename
mp3_files.sort(key=lambda f: parse_chapter_number(f.name))

print(f"Found {len(mp3_files)} MP3 files (sorted by chapter):")
for i, mp3 in enumerate(mp3_files, 1):
    chap_num = parse_chapter_number(mp3.name)
    print(f"  {i:02d}. Chapter {chap_num if chap_num != float('inf') else '?'} -> {mp3.name}")

# 1a. Create concat list
concat_file = "concat.txt"
with open(concat_file, "w", encoding="utf-8") as f:
    for mp3 in mp3_files:
        f.write(f"file '{mp3.as_posix()}'\n")

print("Wrote concat list to:", concat_file)

# 1b. Create FFmetadata with chapters
ffmeta_file = "chapters.ffmetadata"
current_time = 0.0

with open(ffmeta_file, "w", encoding="utf-8") as f:
    f.write(";FFMETADATA1\n")
    for i, mp3 in enumerate(mp3_files, 1):
        duration = get_duration(mp3)
        start_ms = int(current_time * 1000)
        end_ms = int((current_time + duration) * 1000)

        chap_num = parse_chapter_number(mp3.name)
        if chap_num == float("inf"):
            chap_num = i
        chapter_title = f"Chapter {chap_num}"

        f.write("[CHAPTER]\n")
        f.write("TIMEBASE=1/1000\n")
        f.write(f"START={start_ms}\n")
        f.write(f"END={end_ms}\n")
        f.write(f"title={chapter_title}\n\n")

        current_time += duration
        print(f"  -> {chapter_title}: {duration/60:.1f} min")

print("Wrote chapter metadata to:", ffmeta_file)

# 1c. Concatenate MP3s to temporary M4A (AAC 80 kb/s mono)
temp_m4a = "temp_combined.m4a"
print("\n[Step 1] Concatenating MP3 files into AAC M4A (80 kb/s mono)...")
cmd = [
    FFMPEG_BIN, "-y",
    "-f", "concat", "-safe", "0",
    "-i", str(concat_file),
    "-ac", "1",          # mono
    "-c:a", "aac",
    "-b:a", "80k",       # target bitrate
    str(temp_m4a),
]
print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True)

print("Created:", temp_m4a)
print(f"Total duration ~ {current_time/3600:.2f} hours")
# Out:
# Using MP3 folder: D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook
# Found 50 MP3 files (sorted by chapter):
#   01. Chapter 1 -> Harry Potter - Oh God Not Again!  Chapter 1 _ FanFiction AudioBook.mp3
#   02. Chapter 2 -> Harry Potter - Oh God Not Again!  Chapter 2 _ FanFiction AudioBook.mp3
#   03. Chapter 3 -> Harry Potter - Oh God Not Again!  Chapter 3 _ FanFiction AudioBook.mp3
#   04. Chapter 4 -> Harry Potter - Oh God Not Again!  Chapter 4 _ FanFiction AudioBook.mp3
#   05. Chapter 5 -> Harry Potter - Oh God Not Again!  Chapter 5 _ FanFiction AudioBook.mp3
#   06. Chapter 6 -> Harry Potter - Oh God Not Again!  Chapter 6 _ FanFiction AudioBook.mp3
#   07. Chapter 7 -> Harry Potter - Oh God Not Again!  Chapter 7 _ FanFiction AudioBook.mp3
#   08. Chapter 8 -> Harry Potter - Oh God Not Again!  Chapter 8 _ FanFiction AudioBook.mp3
#   09. Chapter 9 -> Harry Potter - Oh God Not Again!  Chapter 9 _ FanFiction AudioBook.mp3
#   10. Chapter 10 -> Harry Potter - Oh God Not Again!  Chapter 10 _ FanFiction AudioBook.mp3
#   11. Chapter 11 -> Harry Potter - Oh God Not Again!  Chapter 11 _ FanFiction AudioBook.mp3
#   12. Chapter 12 -> Harry Potter - Oh God Not Again!  Chapter 12 _ FanFiction AudioBook.mp3
#   13. Chapter 13 -> Harry Potter - Oh God Not Again!  Chapter 13 _ FanFiction AudioBook.mp3
#   14. Chapter 14 -> Harry Potter - Oh God Not Again!  Chapter 14 _ FanFiction AudioBook.mp3
#   15. Chapter 15 -> Harry Potter - Oh God Not Again!  Chapter 15 _ FanFiction AudioBook.mp3
#   16. Chapter 16 -> Harry Potter - Oh God Not Again!  Chapter 16 _ FanFiction AudioBook.mp3
#   17. Chapter 17 -> Harry Potter - Oh God Not Again!  Chapter 17 _ FanFiction AudioBook.mp3
#   46. Chapter 46 -> Harry Potter - Oh God Not Again!  Chapter 46 _ FanFiction AudioBook.mp3
#   47. Chapter 47 -> Harry Potter - Oh God Not Again!  Chapter 47 _ FanFiction AudioBook.mp3
#   48. Chapter 48 -> Harry Potter - Oh God Not Again!  Chapter 48 _ FanFiction AudioBook.mp3
#   49. Chapter 49 -> Harry Potter - Oh God Not Again!  Chapter 49 _ FanFiction AudioBook.mp3
#   50. Chapter 50 -> Harry Potter - Oh God Not Again!  Chapter 50 _ FanFiction AudioBook.mp3
# Wrote concat list to: concat.txt
#   -> Chapter 1: 21.0 min
#   -> Chapter 2: 24.0 min
#   -> Chapter 3: 20.6 min
#   -> Chapter 4: 18.7 min
#   -> Chapter 5: 19.5 min
#   -> Chapter 6: 17.7 min
#   -> Chapter 7: 16.4 min
#   -> Chapter 8: 18.2 min
#   -> Chapter 9: 20.4 min
#   -> Chapter 10: 24.1 min
#   -> Chapter 11: 16.7 min
#   -> Chapter 12: 17.6 min
#   -> Chapter 13: 17.2 min
#   -> Chapter 14: 18.3 min
#   -> Chapter 15: 19.5 min
#   -> Chapter 16: 15.8 min
#   -> Chapter 17: 19.6 min
#   -> Chapter 18: 18.4 min
#   -> Chapter 19: 19.4 min
#   -> Chapter 20: 18.1 min
#   -> Chapter 21: 18.1 min
#   -> Chapter 22: 18.9 min
#   -> Chapter 23: 19.0 min
#   -> Chapter 24: 18.6 min
#   -> Chapter 25: 24.8 min
#   -> Chapter 26: 19.5 min
#   -> Chapter 27: 16.5 min
#   -> Chapter 28: 21.3 min
#   -> Chapter 29: 22.6 min
#   -> Chapter 30: 19.5 min
#   -> Chapter 31: 13.9 min
#   -> Chapter 32: 17.7 min
#   -> Chapter 33: 15.7 min
#   -> Chapter 34: 17.9 min
#   -> Chapter 35: 22.5 min
#   -> Chapter 36: 18.1 min
#   -> Chapter 37: 16.4 min
#   -> Chapter 38: 17.2 min
#   -> Chapter 39: 19.5 min
#   -> Chapter 40: 15.3 min
#   -> Chapter 41: 18.2 min
#   -> Chapter 42: 17.9 min
#   -> Chapter 43: 13.3 min
#   -> Chapter 44: 19.4 min
#   -> Chapter 45: 18.1 min
#   -> Chapter 46: 15.9 min
#   -> Chapter 47: 20.8 min
#   -> Chapter 48: 24.0 min
#   -> Chapter 49: 20.7 min
#   -> Chapter 50: 19.4 min
# Wrote chapter metadata to: chapters.ffmetadata
#
# [Step 1] Concatenating MP3 files into AAC M4A (80 kb/s mono)...
# Running: D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe -y -f concat -safe 0 -i concat.txt -ac 1 -c:a aac -b:a 80k temp_combined.m4a

# %%
#Combine into one m4b with chapters

from pathlib import Path
import subprocess

AUDIO_IN   = "temp_combined.m4a"
FFMETA_IN  = "chapters.ffmetadata"
OUTPUT_M4B = "_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b"

print("Audio in:  ", AUDIO_IN)
print("Meta in:   ", FFMETA_IN)
print("Output m4b:", OUTPUT_M4B)

cmd = [
    FFMPEG_BIN, "-y",
    "-i", str(AUDIO_IN),      # 0: audio
    "-i", str(FFMETA_IN),     # 1: chapters
    "-map_metadata", "1",     # take chapters/metadata from ffmetadata
    "-c", "copy",
    "-metadata", f"title={METADATA['title']}",
    "-metadata", f"artist={METADATA['artist']}",
    "-metadata", f"author={METADATA['author']}",
    "-metadata", f"album={METADATA['album']}",
    "-metadata", f"album_artist={METADATA['album_artist']}",
    "-metadata", f"genre={METADATA['genre']}",
    "-metadata", f"date={METADATA['date']}",
    "-metadata", f"comment={METADATA['comment']}",
    str(OUTPUT_M4B),
]

print("Running:", " ".join(cmd))
result = subprocess.run(cmd, text=True, capture_output=True)
print("\n=== FFmpeg stdout ===\n", result.stdout)
print("\n=== FFmpeg stderr ===\n", result.stderr)
print("\nReturn code:", result.returncode)
# Out:
# Audio in:   temp_combined.m4a
# Meta in:    chapters.ffmetadata
# Output m4b: _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
# Running: D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe -y -i temp_combined.m4a -i chapters.ffmetadata -map_metadata 1 -c copy -metadata title=Oh God Not Again! Harry Potter FanFic -metadata artist=Sarah1281 -metadata author=Sarah1281 -metadata album=Oh God Not Again! Harry Potter FanFic Audiobook -metadata album_artist=Patronus Pages -metadata genre=Audiobook -metadata date=2008 -metadata comment=Patronus Pages YT audiobook: https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD based on Harry Potter FanFic: https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
#
# === FFmpeg stdout ===
#
#
# === FFmpeg stderr ===
#  ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-cairo --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-openal --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      60. 20.100 / 60. 20.100
#   libavcodec     62. 22.101 / 62. 22.101
#   libavformat    62.  6.103 / 62.  6.103
#   libavdevice    62.  2.100 / 62.  2.100
#   libavfilter    11. 10.101 / 11. 10.101
#   libswscale      9.  3.100 /  9.  3.100
#   libswresample   6.  2.100 /  6.  2.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'temp_combined.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 512
#     compatible_brands: M4A isomiso2
#     encoder         : Lavf62.6.103
#   Duration: 15:41:46.64, start: 0.000000, bitrate: 83 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 82 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Input #1, ffmetadata, from 'chapters.ffmetadata':
#   Duration: 15:41:46.64, start: 0.000000, bitrate: N/A
#   Chapters:
#     Chapter #1:0: start 0.000000, end 1257.174000
#       Metadata:
#         title           : Chapter 1
#     Chapter #1:1: start 1257.174000, end 2699.133000
#       Metadata:
#         title           : Chapter 2
#     Chapter #1:2: start 2699.133000, end 3934.621000
#       Metadata:
#         title           : Chapter 3
#     Chapter #1:3: start 3934.621000, end 5057.073000
#       Metadata:
#         title           : Chapter 4
#     Chapter #1:4: start 5057.073000, end 6225.827000
#       Metadata:
#         title           : Chapter 5
#     Chapter #1:5: start 6225.827000, end 7288.650000
#       Metadata:
#         title           : Chapter 6
#     Chapter #1:6: start 7288.650000, end 8272.294000
#       Metadata:
#         title           : Chapter 7
#     Chapter #1:7: start 8272.294000, end 9363.260000
#       Metadata:
#         title           : Chapter 8
#     Chapter #1:8: start 9363.260000, end 10587.207000
#       Metadata:
#         title           : Chapter 9
#     Chapter #1:9: start 10587.207000, end 12031.558000
#       Metadata:
#         title           : Chapter 10
#     Chapter #1:10: start 12031.558000, end 13032.872000
#       Metadata:
#         title           : Chapter 11
#     Chapter #1:11: start 13032.872000, end 14086.803000
#       Metadata:
#         title           : Chapter 12
#     Chapter #1:12: start 14086.803000, end 15120.277000
#       Metadata:
#         title           : Chapter 13
#     Chapter #1:13: start 15120.277000, end 16218.952000
#       Metadata:
#         title           : Chapter 14
#     Chapter #1:14: start 16218.952000, end 17389.354000
#       Metadata:
#         title           : Chapter 15
#     Chapter #1:15: start 17389.354000, end 18339.538000
#       Metadata:
#         title           : Chapter 16
#     Chapter #1:16: start 18339.538000, end 19513.608000
#       Metadata:
#         title           : Chapter 17
#     Chapter #1:17: start 19513.608000, end 20617.346000
#       Metadata:
#         title           : Chapter 18
#     Chapter #1:18: start 20617.346000, end 21780.990000
#       Metadata:
#         title           : Chapter 19
#     Chapter #1:19: start 21780.990000, end 22865.339000
#       Metadata:
#         title           : Chapter 20
#     Chapter #1:20: start 22865.339000, end 23953.217000
#       Metadata:
#         title           : Chapter 21
#     Chapter #1:21: start 23953.217000, end 25089.114000
#       Metadata:
#         title           : Chapter 22
#     Chapter #1:22: start 25089.114000, end 26231.745000
#       Metadata:
#         title           : Chapter 23
#     Chapter #1:23: start 26231.745000, end 27347.022000
#       Metadata:
#         title           : Chapter 24
#     Chapter #1:24: start 27347.022000, end 28834.864000
#       Metadata:
#         title           : Chapter 25
#     Chapter #1:25: start 28834.864000, end 30002.340000
#       Metadata:
#         title           : Chapter 26
#     Chapter #1:26: start 30002.340000, end 30993.740000
#       Metadata:
#         title           : Chapter 27
#     Chapter #1:27: start 30993.740000, end 32270.117000
#       Metadata:
#         title           : Chapter 28
#     Chapter #1:28: start 32270.117000, end 33627.672000
#       Metadata:
#         title           : Chapter 29
#     Chapter #1:29: start 33627.672000, end 34795.264000
#       Metadata:
#         title           : Chapter 30
#     Chapter #1:30: start 34795.264000, end 35627.839000
#       Metadata:
#         title           : Chapter 31
#     Chapter #1:31: start 35627.839000, end 36687.226000
#       Metadata:
#         title           : Chapter 32
#     Chapter #1:32: start 36687.226000, end 37631.164000
#       Metadata:
#         title           : Chapter 33
#     Chapter #1:33: start 37631.164000, end 38705.551000
#       Metadata:
#         title           : Chapter 34
#     Chapter #1:34: start 38705.551000, end 40053.191000
#       Metadata:
#         title           : Chapter 35
#     Chapter #1:35: start 40053.191000, end 41139.420000
#       Metadata:
#         title           : Chapter 36
#     Chapter #1:36: start 41139.420000, end 42122.112000
#       Metadata:
#         title           : Chapter 37
#     Chapter #1:37: start 42122.112000, end 43153.519000
#       Metadata:
#         title           : Chapter 38
#     Chapter #1:38: start 43153.519000, end 44323.410000
#       Metadata:
#         title           : Chapter 39
#     Chapter #1:39: start 44323.410000, end 45241.039000
#       Metadata:
#         title           : Chapter 40
#     Chapter #1:40: start 45241.039000, end 46333.910000
#       Metadata:
#         title           : Chapter 41
#     Chapter #1:41: start 46333.910000, end 47407.206000
#       Metadata:
#         title           : Chapter 42
#     Chapter #1:42: start 47407.206000, end 48205.833000
#       Metadata:
#         title           : Chapter 43
#     Chapter #1:43: start 48205.833000, end 49372.775000
#       Metadata:
#         title           : Chapter 44
#     Chapter #1:44: start 49372.775000, end 50459.051000
#       Metadata:
#         title           : Chapter 45
#     Chapter #1:45: start 50459.051000, end 51414.296000
#       Metadata:
#         title           : Chapter 46
#     Chapter #1:46: start 51414.296000, end 52660.070000
#       Metadata:
#         title           : Chapter 47
#     Chapter #1:47: start 52660.070000, end 54098.198000
#       Metadata:
#         title           : Chapter 48
#     Chapter #1:48: start 54098.198000, end 55342.556000
#       Metadata:
#         title           : Chapter 49
#     Chapter #1:49: start 55342.556000, end 56506.641000
#       Metadata:
#         title           : Chapter 50
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, ipod, to '_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b':
#   Metadata:
#     title           : Oh God Not Again! Harry Potter FanFic
#     artist          : Sarah1281
#     author          : Sarah1281
#     album           : Oh God Not Again! Harry Potter FanFic Audiobook
#     album_artist    : Patronus Pages
#     genre           : Audiobook
#     date            : 2008
#     comment         : Patronus Pages YT audiobook: https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD based on Harry Potter FanFic: https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again
#     encoder         : Lavf62.6.103
#   Chapters:
#     Chapter #0:0: start 0.000000, end 1257.174000
#       Metadata:
#         title           : Chapter 1
#     Chapter #0:1: start 1257.174000, end 2699.133000
#       Metadata:
#         title           : Chapter 2
#     Chapter #0:2: start 2699.133000, end 3934.621000
#       Metadata:
#         title           : Chapter 3
#     Chapter #0:3: start 3934.621000, end 5057.073000
#       Metadata:
#         title           : Chapter 4
#     Chapter #0:4: start 5057.073000, end 6225.827000
#       Metadata:
#         title           : Chapter 5
#     Chapter #0:5: start 6225.827000, end 7288.650000
#       Metadata:
#         title           : Chapter 6
#     Chapter #0:6: start 7288.650000, end 8272.294000
#       Metadata:
#         title           : Chapter 7
#     Chapter #0:7: start 8272.294000, end 9363.260000
#       Metadata:
#         title           : Chapter 8
#     Chapter #0:8: start 9363.260000, end 10587.207000
#       Metadata:
#         title           : Chapter 9
#     Chapter #0:9: start 10587.207000, end 12031.558000
#       Metadata:
#         title           : Chapter 10
#     Chapter #0:10: start 12031.558000, end 13032.872000
#       Metadata:
#         title           : Chapter 11
#     Chapter #0:11: start 13032.872000, end 14086.803000
#       Metadata:
#         title           : Chapter 12
#     Chapter #0:12: start 14086.803000, end 15120.277000
#       Metadata:
#         title           : Chapter 13
#     Chapter #0:13: start 15120.277000, end 16218.952000
#       Metadata:
#         title           : Chapter 14
#     Chapter #0:14: start 16218.952000, end 17389.354000
#       Metadata:
#         title           : Chapter 15
#     Chapter #0:15: start 17389.354000, end 18339.538000
#       Metadata:
#         title           : Chapter 16
#     Chapter #0:16: start 18339.538000, end 19513.608000
#       Metadata:
#         title           : Chapter 17
#     Chapter #0:17: start 19513.608000, end 20617.346000
#       Metadata:
#         title           : Chapter 18
#     Chapter #0:18: start 20617.346000, end 21780.990000
#       Metadata:
#         title           : Chapter 19
#     Chapter #0:19: start 21780.990000, end 22865.339000
#       Metadata:
#         title           : Chapter 20
#     Chapter #0:20: start 22865.339000, end 23953.217000
#       Metadata:
#         title           : Chapter 21
#     Chapter #0:21: start 23953.217000, end 25089.114000
#       Metadata:
#         title           : Chapter 22
#     Chapter #0:22: start 25089.114000, end 26231.745000
#       Metadata:
#         title           : Chapter 23
#     Chapter #0:23: start 26231.745000, end 27347.022000
#       Metadata:
#         title           : Chapter 24
#     Chapter #0:24: start 27347.022000, end 28834.864000
#       Metadata:
#         title           : Chapter 25
#     Chapter #0:25: start 28834.864000, end 30002.340000
#       Metadata:
#         title           : Chapter 26
#     Chapter #0:26: start 30002.340000, end 30993.740000
#       Metadata:
#         title           : Chapter 27
#     Chapter #0:27: start 30993.740000, end 32270.117000
#       Metadata:
#         title           : Chapter 28
#     Chapter #0:28: start 32270.117000, end 33627.672000
#       Metadata:
#         title           : Chapter 29
#     Chapter #0:29: start 33627.672000, end 34795.264000
#       Metadata:
#         title           : Chapter 30
#     Chapter #0:30: start 34795.264000, end 35627.839000
#       Metadata:
#         title           : Chapter 31
#     Chapter #0:31: start 35627.839000, end 36687.226000
#       Metadata:
#         title           : Chapter 32
#     Chapter #0:32: start 36687.226000, end 37631.164000
#       Metadata:
#         title           : Chapter 33
#     Chapter #0:33: start 37631.164000, end 38705.551000
#       Metadata:
#         title           : Chapter 34
#     Chapter #0:34: start 38705.551000, end 40053.191000
#       Metadata:
#         title           : Chapter 35
#     Chapter #0:35: start 40053.191000, end 41139.420000
#       Metadata:
#         title           : Chapter 36
#     Chapter #0:36: start 41139.420000, end 42122.112000
#       Metadata:
#         title           : Chapter 37
#     Chapter #0:37: start 42122.112000, end 43153.519000
#       Metadata:
#         title           : Chapter 38
#     Chapter #0:38: start 43153.519000, end 44323.410000
#       Metadata:
#         title           : Chapter 39
#     Chapter #0:39: start 44323.410000, end 45241.039000
#       Metadata:
#         title           : Chapter 40
#     Chapter #0:40: start 45241.039000, end 46333.910000
#       Metadata:
#         title           : Chapter 41
#     Chapter #0:41: start 46333.910000, end 47407.206000
#       Metadata:
#         title           : Chapter 42
#     Chapter #0:42: start 47407.206000, end 48205.833000
#       Metadata:
#         title           : Chapter 43
#     Chapter #0:43: start 48205.833000, end 49372.775000
#       Metadata:
#         title           : Chapter 44
#     Chapter #0:44: start 49372.775000, end 50459.051000
#       Metadata:
#         title           : Chapter 45
#     Chapter #0:45: start 50459.051000, end 51414.296000
#       Metadata:
#         title           : Chapter 46
#     Chapter #0:46: start 51414.296000, end 52660.070000
#       Metadata:
#         title           : Chapter 47
#     Chapter #0:47: start 52660.070000, end 54098.198000
#       Metadata:
#         title           : Chapter 48
#     Chapter #0:48: start 54098.198000, end 55342.556000
#       Metadata:
#         title           : Chapter 49
#     Chapter #0:49: start 55342.556000, end 56506.641000
#       Metadata:
#         title           : Chapter 50
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp,
# size=  526081KiB time=14:29:51.21 bitrate=  82.6kbits/s speed= 722x elapsed=0:01:12.25
# size=  528129KiB time=14:33:25.20 bitrate=  82.6kbits/s speed= 720x elapsed=0:01:12.78
# size=  530177KiB time=14:36:35.42 bitrate=  82.6kbits/s speed= 718x elapsed=0:01:13.30
# size=  532225KiB time=14:40:09.42 bitrate=  82.6kbits/s speed= 715x elapsed=0:01:13.81
# size=  534273KiB time=14:43:19.63 bitrate=  82.6kbits/s speed= 713x elapsed=0:01:14.33
# size=  536321KiB time=14:46:34.57 bitrate=  82.6kbits/s speed= 711x elapsed=0:01:14.85
# size=  538369KiB time=14:50:03.85 bitrate=  82.6kbits/s speed= 708x elapsed=0:01:15.38
# size=  540417KiB time=14:53:37.84 bitrate=  82.6kbits/s speed= 706x elapsed=0:01:15.91
# size=  542209KiB time=14:56:24.28 bitrate=  82.6kbits/s speed= 704x elapsed=0:01:16.41
# size=  544257KiB time=14:59:58.28 bitrate=  82.6kbits/s speed= 702x elapsed=0:01:16.94
# size=  546305KiB time=15:03:08.50 bitrate=  82.6kbits/s speed= 700x elapsed=0:01:17.44
# size=  548353KiB time=15:06:42.49 bitrate=  82.6kbits/s speed= 698x elapsed=0:01:17.97
# size=  550401KiB time=15:09:52.71 bitrate=  82.6kbits/s speed= 696x elapsed=0:01:18.47
# size=  552449KiB time=15:13:26.70 bitrate=  82.6kbits/s speed= 694x elapsed=0:01:19.00
# size=  555265KiB time=15:17:48.25 bitrate=  82.6kbits/s speed= 693x elapsed=0:01:19.51
# size=  557825KiB time=15:22:09.80 bitrate=  82.6kbits/s speed= 691x elapsed=0:01:20.03
# size=  560129KiB time=15:26:07.58 bitrate=  82.6kbits/s speed= 690x elapsed=0:01:20.55
# size=  562689KiB time=15:30:29.13 bitrate=  82.6kbits/s speed= 689x elapsed=0:01:21.07
# size=  565249KiB time=15:34:26.90 bitrate=  82.6kbits/s speed= 687x elapsed=0:01:21.60
# size=  567809KiB time=15:38:48.45 bitrate=  82.6kbits/s speed= 686x elapsed=0:01:22.10
# [out#0/ipod @ 0000022286802680] video:0KiB audio:569776KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.670679%
# size=  579295KiB time=15:41:46.64 bitrate=  84.0kbits/s speed= 684x elapsed=0:01:22.56
#
#
# Return code: 0

# %%
#Add embeded cover

import subprocess
from pathlib import Path

folder = MP3_FOLDER

INPUT_M4B  = "_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b"
COVER_IMG  = folder / "cover_thumbnail.jpg"    # or .png
OUTPUT_M4B = folder / "Oh_God_Not_Again_Harry_Potter_FanFic.m4b"

print("Input m4b: ", INPUT_M4B)
print("Cover:     ", COVER_IMG)
print("Output m4b:", OUTPUT_M4B)

if not COVER_IMG.exists():
    raise SystemExit(f"Cover image not found: {COVER_IMG}")

cmd = [
    FFMPEG_BIN, "-y",
    "-i", str(INPUT_M4B),      # 0: audio+chapters
    "-i", str(COVER_IMG),      # 1: cover
    "-map", "0:a",             # audio
    "-map", "0:t?",            # existing chapters/metadata
    "-map", "1:v",             # cover image
    "-c", "copy",
    "-c:v", "mjpeg" if COVER_IMG.suffix.lower() in [".jpg", ".jpeg"] else "png",
    "-disposition:v:0", "attached_pic",
    str(OUTPUT_M4B),
]

print("Running:", " ".join(cmd))
result = subprocess.run(cmd, text=True, capture_output=True)
print("\n=== FFmpeg stdout ===\n", result.stdout)
print("\n=== FFmpeg stderr ===\n", result.stderr)
print("\nReturn code:", result.returncode)
# Out:
# Input m4b:  _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
# Cover:      D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\cover_thumbnail.jpg
# Output m4b: D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\Oh_God_Not_Again_Harry_Potter_FanFic.m4b
# Running: D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe -y -i _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b -i D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\cover_thumbnail.jpg -map 0:a -map 0:t? -map 1:v -c copy -c:v mjpeg -disposition:v:0 attached_pic D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\Oh_God_Not_Again_Harry_Potter_FanFic.m4b
#
# === FFmpeg stdout ===
#
#
# === FFmpeg stderr ===
#  ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-cairo --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-sdl2 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-openal --enable-libgme --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libtheora --enable-libvo-amrwbenc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-librubberband
#   libavutil      60. 20.100 / 60. 20.100
#   libavcodec     62. 22.101 / 62. 22.101
#   libavformat    62.  6.103 / 62.  6.103
#   libavdevice    62.  2.100 / 62.  2.100
#   libavfilter    11. 10.101 / 11. 10.101
#   libswscale      9.  3.100 /  9.  3.100
#   libswresample   6.  2.100 /  6.  2.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 512
#     compatible_brands: M4A isomiso2
#     title           : Oh God Not Again! Harry Potter FanFic
#     artist          : Sarah1281
#     album_artist    : Patronus Pages
#     album           : Oh God Not Again! Harry Potter FanFic Audiobook
#     date            : 2008
#     encoder         : Lavf62.6.103
#     comment         : Patronus Pages YT audiobook: https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD based on Harry Potter FanFic: https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again
#     genre           : Audiobook
#   Duration: 15:41:46.64, start: 0.000000, bitrate: 83 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 1257.174000
#       Metadata:
#         title           : Chapter 1
#     Chapter #0:1: start 1257.174000, end 2699.133000
#       Metadata:
#         title           : Chapter 2
#     Chapter #0:2: start 2699.133000, end 3934.621000
#       Metadata:
#         title           : Chapter 3
#     Chapter #0:3: start 3934.621000, end 5057.073000
#       Metadata:
#         title           : Chapter 4
#     Chapter #0:4: start 5057.073000, end 6225.827000
#       Metadata:
#         title           : Chapter 5
#     Chapter #0:5: start 6225.827000, end 7288.650000
#       Metadata:
#         title           : Chapter 6
#     Chapter #0:6: start 7288.650000, end 8272.294000
#       Metadata:
#         title           : Chapter 7
#     Chapter #0:7: start 8272.294000, end 9363.260000
#       Metadata:
#         title           : Chapter 8
#     Chapter #0:8: start 9363.260000, end 10587.207000
#       Metadata:
#         title           : Chapter 9
#     Chapter #0:9: start 10587.207000, end 12031.558000
#       Metadata:
#         title           : Chapter 10
#     Chapter #0:10: start 12031.558000, end 13032.872000
#       Metadata:
#         title           : Chapter 11
#     Chapter #0:11: start 13032.872000, end 14086.803000
#       Metadata:
#         title           : Chapter 12
#     Chapter #0:12: start 14086.803000, end 15120.277000
#       Metadata:
#         title           : Chapter 13
#     Chapter #0:13: start 15120.277000, end 16218.952000
#       Metadata:
#         title           : Chapter 14
#     Chapter #0:14: start 16218.952000, end 17389.354000
#       Metadata:
#         title           : Chapter 15
#     Chapter #0:15: start 17389.354000, end 18339.538000
#       Metadata:
#         title           : Chapter 16
#     Chapter #0:16: start 18339.538000, end 19513.608000
#       Metadata:
#         title           : Chapter 17
#     Chapter #0:17: start 19513.608000, end 20617.346000
#       Metadata:
#         title           : Chapter 18
#     Chapter #0:18: start 20617.346000, end 21780.990000
#       Metadata:
#         title           : Chapter 19
#     Chapter #0:19: start 21780.990000, end 22865.339000
#       Metadata:
#         title           : Chapter 20
#     Chapter #0:20: start 22865.339000, end 23953.217000
#       Metadata:
#         title           : Chapter 21
#     Chapter #0:21: start 23953.217000, end 25089.114000
#       Metadata:
#         title           : Chapter 22
#     Chapter #0:22: start 25089.114000, end 26231.745000
#       Metadata:
#         title           : Chapter 23
#     Chapter #0:23: start 26231.745000, end 27347.022000
#       Metadata:
#         title           : Chapter 24
#     Chapter #0:24: start 27347.022000, end 28834.864000
#       Metadata:
#         title           : Chapter 25
#     Chapter #0:25: start 28834.864000, end 30002.340000
#       Metadata:
#         title           : Chapter 26
#     Chapter #0:26: start 30002.340000, end 30993.740000
#       Metadata:
#         title           : Chapter 27
#     Chapter #0:27: start 30993.740000, end 32270.117000
#       Metadata:
#         title           : Chapter 28
#     Chapter #0:28: start 32270.117000, end 33627.672000
#       Metadata:
#         title           : Chapter 29
#     Chapter #0:29: start 33627.672000, end 34795.264000
#       Metadata:
#         title           : Chapter 30
#     Chapter #0:30: start 34795.264000, end 35627.839000
#       Metadata:
#         title           : Chapter 31
#     Chapter #0:31: start 35627.839000, end 36687.226000
#       Metadata:
#         title           : Chapter 32
#     Chapter #0:32: start 36687.226000, end 37631.164000
#       Metadata:
#         title           : Chapter 33
#     Chapter #0:33: start 37631.164000, end 38705.551000
#       Metadata:
#         title           : Chapter 34
#     Chapter #0:34: start 38705.551000, end 40053.191000
#       Metadata:
#         title           : Chapter 35
#     Chapter #0:35: start 40053.191000, end 41139.420000
#       Metadata:
#         title           : Chapter 36
#     Chapter #0:36: start 41139.420000, end 42122.112000
#       Metadata:
#         title           : Chapter 37
#     Chapter #0:37: start 42122.112000, end 43153.519000
#       Metadata:
#         title           : Chapter 38
#     Chapter #0:38: start 43153.519000, end 44323.410000
#       Metadata:
#         title           : Chapter 39
#     Chapter #0:39: start 44323.410000, end 45241.039000
#       Metadata:
#         title           : Chapter 40
#     Chapter #0:40: start 45241.039000, end 46333.910000
#       Metadata:
#         title           : Chapter 41
#     Chapter #0:41: start 46333.910000, end 47407.206000
#       Metadata:
#         title           : Chapter 42
#     Chapter #0:42: start 47407.206000, end 48205.833000
#       Metadata:
#         title           : Chapter 43
#     Chapter #0:43: start 48205.833000, end 49372.775000
#       Metadata:
#         title           : Chapter 44
#     Chapter #0:44: start 49372.775000, end 50459.051000
#       Metadata:
#         title           : Chapter 45
#     Chapter #0:45: start 50459.051000, end 51414.296000
#       Metadata:
#         title           : Chapter 46
#     Chapter #0:46: start 51414.296000, end 52660.070000
#       Metadata:
#         title           : Chapter 47
#     Chapter #0:47: start 52660.070000, end 54098.198000
#       Metadata:
#         title           : Chapter 48
#     Chapter #0:48: start 54098.198000, end 55342.556000
#       Metadata:
#         title           : Chapter 49
#     Chapter #0:49: start 55342.556000, end 56506.641000
#       Metadata:
#         title           : Chapter 50
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 82 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#   Stream #0:1[0x2](eng): Data: bin_data (text / 0x74786574)
#     Metadata:
#       handler_name    : SubtitleHandler
# Input #1, image2, from 'D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\cover_thumbnail.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 9204 kb/s
#   Stream #1:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 480x480 [SAR 1:1 DAR 1:1], 25 fps, 25 tbr, 25 tbn
# [vost#0:1 @ 000001507e7e7c40] Multiple -codec/-c/-acodec/-vcodec/-scodec/-dcodec options specified for stream 1, only the last option '-codec:v mjpeg' will be used.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, ipod, to 'D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\Oh_God_Not_Again_Harry_Potter_FanFic.m4b':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 512
#     compatible_brands: M4A isomiso2
#     title           : Oh God Not Again! Harry Potter FanFic
#     artist          : Sarah1281
#     album_artist    : Patronus Pages
#     album           : Oh God Not Again! Harry Potter FanFic Audiobook
#     date            : 2008
#     genre           : Audiobook
#     comment         : Patronus Pages YT audiobook: https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD based on Harry Potter FanFic: https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again
#     encoder         : Lavf62.6.103
#   Chapters:
#     Chapter #0:0: start 0.000000, end 1257.174000
#       Metadata:
#         title           : Chapter 1
#     Chapter #0:1: start 1257.174000, end 2699.133000
#       Metadata:
#         title           : Chapter 2
#     Chapter #0:2: start 2699.133000, end 3934.621000
#       Metadata:
#         title           : Chapter 3
#     Chapter #0:3: start 3934.621000, end 5057.073000
#       Metadata:
#         title           : Chapter 4
#     Chapter #0:4: start 5057.073000, end 6225.827000
#       Metadata:
#         title           : Chapter 5
#     Chapter #0:5: start 6225.827000, end 7288.650000
#       Metadata:
#         title           : Chapter 6
#     Chapter #0:6: start 7288.650000, end 8272.294000
#       Metadata:
#         title           : Chapter 7
#     Chapter #0:7: start 8272.294000, end 9363.260000
#       Metadata:
#         title           : Chapter 8
#     Chapter #0:8: start 9363.260000, end 10587.207000
#       Metadata:
#         title           : Chapter 9
#     Chapter #0:9: start 10587.207000, end 12031.558000
#       Metadata:
#         title           : Chapter 10
#     Chapter #0:10: start 12031.558000, end 13032.872000
#       Metadata:
#         title           : Chapter 11
#     Chapter #0:11: start 13032.872000, end 14086.803000
#       Metadata:
#         title           : Chapter 12
#     Chapter #0:12: start 14086.803000, end 15120.277000
#       Metadata:
#         title           : Chapter 13
#     Chapter #0:13: start 15120.277000, end 16218.952000
#       Metadata:
#         title           : Chapter 14
#     Chapter #0:14: start 16218.952000, end 17389.354000
#       Metadata:
#         title           : Chapter 15
#     Chapter #0:15: start 17389.354000, end 18339.538000
#       Metadata:
#         title           : Chapter 16
#     Chapter #0:16: start 18339.538000, end 19513.608000
#       Metadata:
#         title           : Chapter 17
#     Chapter #0:17: start 19513.608000, end 20617.346000
#       Metadata:
#         title           : Chapter 18
#     Chapter #0:18: start 20617.346000, end 21780.990000
#       Metadata:
#         title           : Chapter 19
#     Chapter #0:19: start 21780.990000, end 22865.339000
#       Metadata:
#         title           : Chapter 20
#     Chapter #0:20: start 22865.339000, end 23953.217000
#       Metadata:
#         title           : Chapter 21
#     Chapter #0:21: start 23953.217000, end 25089.114000
#       Metadata:
#         title           : Chapter 22
#     Chapter #0:22: start 25089.114000, end 26231.745000
#       Metadata:
#         title           : Chapter 23
#     Chapter #0:23: start 26231.745000, end 27347.022000
#       Metadata:
#         title           : Chapter 24
#     Chapter #0:24: start 27347.022000, end 28834.864000
#       Metadata:
#         title           : Chapter 25
#     Chapter #0:25: start 28834.864000, end 30002.340000
#       Metadata:
#         title           : Chapter 26
#     Chapter #0:26: start 30002.340000, end 30993.740000
#       Metadata:
#         title           : Chapter 27
#     Chapter #0:27: start 30993.740000, end 32270.117000
#       Metadata:
#         title           : Chapter 28
#     Chapter #0:28: start 32270.117000, end 33627.672000
#       Metadata:
#         title           : Chapter 29
#     Chapter #0:29: start 33627.672000, end 34795.264000
#       Metadata:
#         title           : Chapter 30
#     Chapter #0:30: start 34795.264000, end 35627.839000
#       Metadata:
#         title           : Chapter 31
#     Chapter #0:31: start 35627.839000, end 36687.226000
#       Metadata:
#         title           : Chapter 32
#     Chapter #0:32: start 36687.226000, end 37631.164000
#       Metadata:
#         title           : Chapter 33
#     Chapter #0:33: start 37631.164000, end 38705.551000
#       Metadata:
#         title           : Chapter 34
#     Chapter #0:34: start 38705.551000, end 40053.191000
#       Metadata:
#         title           : Chapter 35
#     Chapter #0:35: start 40053.191000, end 41139.420000
#       Metadata:
#         title           : Chapter 36
#     Chapter #0:36: start 41139.420000, end 42122.112000
#       Metadata:
#         title           : Chapter 37
#     Chapter #0:37: start 42122.112000, end 43153.519000
#       Metadata:
#         title           : Chapter 38
#     Chapter #0:38: start 43153.519000, end 44323.410000
#       Metadata:
#         title           : Chapter 39
#     Chapter #0:39: start 44323.410000, end 45241.039000
#       Metadata:
#         title           : Chapter 40
#     Chapter #0:40: start 45241.039000, end 46333.910000
#       Metadata:
#         title           : Chapter 41
#     Chapter #0:41: start 46333.910000, end 47407.206000
#       Metadata:
#         title           : Chapter 42
#     Chapter #0:42: start 47407.206000, end 48205.833000
#       Metadata:
#         title           : Chapter 43
#     Chapter #0:43: start 48205.833000, end 49372.775000
#       Metadata:
#         title           : Chapter 44
#     Chapter #0:44: start 49372.775000, end 50459.051000
#       Metadata:
#         title           : Chapter 45
#     Chapter #0:45: start 50459.051000, end 51414.296000
#       Metadata:
#         title           : Chapter 46
#     Chapter #0:46: start 51414.296000, end 52660.070000
#       Metadata:
#         title           : Chapter 47
#     Chapter #0:47: start 52660.070000, end 54098.198000
#       Metadata:
#         title           : Chapter 48
#     Chapter #0:48: start 54098.198000, end 55342.556000
#       Metadata:
#         title           : Chapter 49
#     Chapter #0:49: start 55342.556000, end 56506.641000
#       Metadata:
#         title           : Chapter 50
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 82 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#   Stream #0:1: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 480x480 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 12800 tbn (attached pic)
#     Metadata:
#       encoder         : Lavc62.22.101 mjpeg
#     Side data:
#       CPB properties: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=6.9 size=   34817KiB time=00:58:01.66 bitrate=  81.9kbits/s speed=6.83e+03x elapsed=0:00:00.50
# frame=    1 fps=1.0 q=6.9 size=   56833KiB time=01:34:05.79 bitrate=  82.5kbits/s speed=5.44e+03x elapsed=0:00:01.03
# frame=    1 fps=0.6 q=6.9 size=   75009KiB time=02:04:12.46 bitrate=  82.5kbits/s speed=4.82e+03x elapsed=0:00:01.54
# frame=    1 fps=0.5 q=6.9 size=   89089KiB time=02:27:20.37 bitrate=  82.6kbits/s speed=4.27e+03x elapsed=0:00:02.06
# frame=    1 fps=0.4 q=6.9 size=  102401KiB time=02:49:30.27 bitrate=  82.5kbits/s speed=3.94e+03x elapsed=0:00:02.57
# frame=    1 fps=0.3 q=6.9 size=  114177KiB time=03:08:48.15 bitrate=  82.6kbits/s speed=3.65e+03x elapsed=0:00:03.10
# frame=    1 fps=0.3 q=6.9 size=  125441KiB time=03:27:25.68 bitrate=  82.6kbits/s speed=3.45e+03x elapsed=0:00:03.60
# frame=    1 fps=0.2 q=6.9 size=  134913KiB time=03:43:16.77 bitrate=  82.5kbits/s speed=3.25e+03x elapsed=0:00:04.11
# frame=    1 fps=0.2 q=6.9 size=  145153KiB time=03:59:55.41 bitrate=  82.6kbits/s speed=3.1e+03x elapsed=0:00:04.64
# frame=    1 fps=0.2 q=6.9 size=  153601KiB time=04:14:11.40 bitrate=  82.5kbits/s speed=2.96e+03x elapsed=0:00:05.15
# frame=    1 fps=0.2 q=6.9 size=  163073KiB time=04:29:38.71 bitrate=  82.6kbits/s speed=2.85e+03x elapsed=0:00:05.67
# frame=    1 fps=0.2 q=6.9 size=  171009KiB time=04:42:43.36 bitrate=  82.6kbits/s speed=2.74e+03x elapsed=0:00:06.18
# frame=    1 fps=0.1 q=6.9 size=  178945KiB time=04:55:48.00 bitrate=  82.6kbits/s speed=2.65e+03x elapsed=0:00:06.70
# frame=    1 fps=0.1 q=6.9 size=  309505KiB time=08:31:22.82 bitrate=  82.6kbits/s speed=1.7e+03x elapsed=0:00:18.04
# frame=    1 fps=0.1 q=6.9 size=  314369KiB time=08:39:43.95 bitrate=  82.6kbits/s speed=1.68e+03x elapsed=0:00:18.56
# frame=    1 fps=0.1 q=6.9 size=  318721KiB time=08:46:50.13 bitrate=  82.6kbits/s speed=1.66e+03x elapsed=0:00:19.07
# frame=    1 fps=0.1 q=6.9 size=  323585KiB time=08:55:09.45 bitrate=  82.6kbits/s speed=1.64e+03x elapsed=0:00:19.59
# frame=    1 fps=0.0 q=6.9 size=  327937KiB time=09:02:17.44 bitrate=  82.6kbits/s speed=1.62e+03x elapsed=0:00:20.10
# frame=    1 fps=0.0 q=6.9 size=  332801KiB time=09:10:12.99 bitrate=  82.6kbits/s speed=1.6e+03x elapsed=0:00:20.62
# frame=    1 fps=0.0 q=6.9 size=  336897KiB time=09:17:08.07 bitrate=  82.6kbits/s speed=1.58e+03x elapsed=0:00:21.13
# frame=    1 fps=0.0 q=6.9 size=  341505KiB time=09:24:28.97 bitrate=  82.6kbits/s speed=1.56e+03x elapsed=0:00:21.64
# frame=    1 fps=0.0 q=6.9 size=  345601KiB time=09:31:13.18 bitrate=  82.6kbits/s speed=1.55e+03x elapsed=0:00:22.17
# frame=    1 fps=0.0 q=6.9 size=  349697KiB time=09:38:21.17 bitrate=  82.6kbits/s speed=1.53e+03x elapsed=0:00:22.69
# frame=    1 fps=0.0 q=6.9 size=  354049KiB time=09:45:29.16 bitrate=  82.6kbits/s speed=1.51e+03x elapsed=0:00:23.20
# frame=    1 fps=0.0 q=6.9 size=  358145KiB time=09:52:13.38 bitrate=  82.6kbits/s speed=1.5e+03x elapsed=0:00:23.72
# frame=    1 fps=0.0 q=6.9 size=  362241KiB time=09:58:57.59 bitrate=  82.6kbits/s speed=1.48e+03x elapsed=0:00:24.23
# frame=    1 fps=0.0 q=6.9 size=  366337KiB time=10:05:41.80 bitrate=  82.6kbits/s speed=1.47e+03x elapsed=0:00:24.75
# frame=    1 fps=0.0 q=6.9 size=  370689KiB time=10:12:49.79 bitrate=  82.6kbits/s speed=1.46e+03x elapsed=0:00:25.26
# frame=    1 fps=0.0 q=6.9 size=  374273KiB time=10:18:46.45 bitrate=  82.6kbits/s speed=1.44e+03x elapsed=0:00:25.78
# frame=    1 fps=0.0 q=6.9 size=  378369KiB time=10:25:30.66 bitrate=  82.6kbits/s speed=1.43e+03x elapsed=0:00:26.30
# frame=    1 fps=0.0 q=6.9 size=  381953KiB time=10:31:27.32 bitrate=  82.6kbits/s speed=1.41e+03x elapsed=0:00:26.81
# frame=    1 fps=0.0 q=6.9 size=  386305KiB time=10:38:35.31 bitrate=  82.6kbits/s speed=1.4e+03x elapsed=0:00:27.33
# frame=    1 fps=0.0 q=6.9 size=  389889KiB time=10:44:31.97 bitrate=  82.6kbits/s speed=1.39e+03x elapsed=0:00:27.84
# frame=    1 fps=0.0 q=6.9 size=  393985KiB time=10:51:16.18 bitrate=  82.6kbits/s speed=1.38e+03x elapsed=0:00:28.36
# frame=    1 fps=0.0 q=6.9 size=  397313KiB time=10:56:49.06 bitrate=  82.6kbits/s speed=1.36e+03x elapsed=0:00:28.87
# frame=    1 fps=0.0 q=6.9 size=  401153KiB time=11:03:09.50 bitrate=  82.6kbits/s speed=1.35e+03x elapsed=0:00:29.38
# frame=    1 fps=0.0 q=6.9 size=  404481KiB time=11:08:42.38 bitrate=  82.6kbits/s speed=1.34e+03x elapsed=0:00:29.90
# frame=    1 fps=0.0 q=6.9 size=  408577KiB time=11:15:26.59 bitrate=  82.6kbits/s speed=1.33e+03x elapsed=0:00:30.41
# frame=    1 fps=0.0 q=6.9 size=  411905KiB time=11:20:59.48 bitrate=  82.6kbits/s speed=1.32e+03x elapsed=0:00:30.93
# frame=    1 fps=0.0 q=6.9 size=  415745KiB time=11:27:24.72 bitrate=  82.6kbits/s speed=1.31e+03x elapsed=0:00:31.44
# frame=    1 fps=0.0 q=6.9 size=  419073KiB time=11:32:52.79 bitrate=  82.6kbits/s speed=1.3e+03x elapsed=0:00:31.96
# frame=    1 fps=0.0 q=6.9 size=  423169KiB time=11:39:18.06 bitrate=  82.6kbits/s speed=1.29e+03x elapsed=0:00:32.48
# frame=    1 fps=0.0 q=6.9 size=  426241KiB time=11:44:46.11 bitrate=  82.6kbits/s speed=1.28e+03x elapsed=0:00:32.99
# frame=    1 fps=0.0 q=6.9 size=  430081KiB time=11:51:06.55 bitrate=  82.6kbits/s speed=1.27e+03x elapsed=0:00:33.52
# frame=    1 fps=0.0 q=6.9 size=  433409KiB time=11:56:15.65 bitrate=  82.6kbits/s speed=1.26e+03x elapsed=0:00:34.03
# frame=    1 fps=0.0 q=6.9 size=  437249KiB time=12:02:36.09 bitrate=  82.6kbits/s speed=1.25e+03x elapsed=0:00:34.55
# frame=    1 fps=0.0 q=6.9 size=  440321KiB time=12:07:45.19 bitrate=  82.6kbits/s speed=1.25e+03x elapsed=0:00:35.06
# frame=    1 fps=0.0 q=6.9 size=  444161KiB time=12:14:05.63 bitrate=  82.6kbits/s speed=1.24e+03x elapsed=0:00:35.58
# frame=    1 fps=0.0 q=6.9 size=  446977KiB time=12:18:51.81 bitrate=  82.6kbits/s speed=1.23e+03x elapsed=0:00:36.09
# frame=    1 fps=0.0 q=6.9 size=  450561KiB time=12:24:47.61 bitrate=  82.6kbits/s speed=1.22e+03x elapsed=0:00:36.61
# frame=    1 fps=0.0 q=6.9 size=  453633KiB time=12:29:56.71 bitrate=  82.6kbits/s speed=1.21e+03x elapsed=0:00:37.12
# frame=    1 fps=0.0 q=6.9 size=  456961KiB time=12:35:29.60 bitrate=  82.6kbits/s speed=1.2e+03x elapsed=0:00:37.63
# frame=    1 fps=0.0 q=6.9 size=  460289KiB time=12:41:02.48 bitrate=  82.6kbits/s speed=1.2e+03x elapsed=0:00:38.15
# frame=    1 fps=0.0 q=6.9 size=  463617KiB time=12:46:15.44 bitrate=  82.6kbits/s speed=1.19e+03x elapsed=0:00:38.66
# frame=    1 fps=0.0 q=6.9 size=  466689KiB time=12:51:44.46 bitrate=  82.6kbits/s speed=1.18e+03x elapsed=0:00:39.19
# frame=    1 fps=0.0 q=6.9 size=  470017KiB time=12:56:53.57 bitrate=  82.6kbits/s speed=1.17e+03x elapsed=0:00:39.70
# frame=    1 fps=0.0 q=6.9 size=  473345KiB time=13:02:26.45 bitrate=  82.6kbits/s speed=1.17e+03x elapsed=0:00:40.22
# frame=    1 fps=0.0 q=6.9 size=  475649KiB time=13:06:24.22 bitrate=  82.6kbits/s speed=1.16e+03x elapsed=0:00:40.73
# frame=    1 fps=0.0 q=6.9 size=  478465KiB time=13:11:09.55 bitrate=  82.6kbits/s speed=1.15e+03x elapsed=0:00:41.25
# frame=    1 fps=0.0 q=6.9 size=  481281KiB time=13:15:54.87 bitrate=  82.6kbits/s speed=1.14e+03x elapsed=0:00:41.76
# frame=    1 fps=0.0 q=6.9 size=  484609KiB time=13:21:03.98 bitrate=  82.6kbits/s speed=1.14e+03x elapsed=0:00:42.28
# frame=    1 fps=0.0 q=6.9 size=  487425KiB time=13:25:49.30 bitrate=  82.6kbits/s speed=1.13e+03x elapsed=0:00:42.80
# frame=    1 fps=0.0 q=6.9 size=  490753KiB time=13:31:19.52 bitrate=  82.6kbits/s speed=1.12e+03x elapsed=0:00:43.32
# frame=    1 fps=0.0 q=6.9 size=  493313KiB time=13:35:43.74 bitrate=  82.6kbits/s speed=1.12e+03x elapsed=0:00:43.83
# frame=    1 fps=0.0 q=6.9 size=  496641KiB time=13:41:16.62 bitrate=  82.6kbits/s speed=1.11e+03x elapsed=0:00:44.36
# frame=    1 fps=0.0 q=6.9 size=  499457KiB time=13:46:01.94 bitrate=  82.6kbits/s speed=1.1e+03x elapsed=0:00:44.87
# frame=    1 fps=0.0 q=6.9 size=  502785KiB time=13:51:34.82 bitrate=  82.5kbits/s speed=1.1e+03x elapsed=0:00:45.39
# frame=    1 fps=0.0 q=6.9 size=  505601KiB time=13:55:56.37 bitrate=  82.6kbits/s speed=1.09e+03x elapsed=0:00:45.90
# frame=    1 fps=0.0 q=6.9 size=  508929KiB time=14:01:29.26 bitrate=  82.6kbits/s speed=1.09e+03x elapsed=0:00:46.42
# frame=    1 fps=0.0 q=6.9 size=  511489KiB time=14:05:50.80 bitrate=  82.6kbits/s speed=1.08e+03x elapsed=0:00:46.93
# frame=    1 fps=0.0 q=6.9 size=  514817KiB time=14:11:23.69 bitrate=  82.6kbits/s speed=1.08e+03x elapsed=0:00:47.45
# frame=    1 fps=0.0 q=6.9 size=  517633KiB time=14:15:45.24 bitrate=  82.6kbits/s speed=1.07e+03x elapsed=0:00:47.96
# frame=    1 fps=0.0 q=6.9 size=  520705KiB time=14:20:56.94 bitrate=  82.6kbits/s speed=1.07e+03x elapsed=0:00:48.48
# frame=    1 fps=0.0 q=6.9 size=  523265KiB time=14:25:15.89 bitrate=  82.6kbits/s speed=1.06e+03x elapsed=0:00:48.99
# frame=    1 fps=0.0 q=6.9 size=  526337KiB time=14:30:24.99 bitrate=  82.6kbits/s speed=1.05e+03x elapsed=0:00:49.51
# frame=    1 fps=0.0 q=6.9 size=  528897KiB time=14:34:46.54 bitrate=  82.5kbits/s speed=1.05e+03x elapsed=0:00:50.02
# frame=    1 fps=0.0 q=6.9 size=  531969KiB time=14:39:31.87 bitrate=  82.6kbits/s speed=1.04e+03x elapsed=0:00:50.55
# frame=    1 fps=0.0 q=6.9 size=  534529KiB time=14:43:53.42 bitrate=  82.6kbits/s speed=1.04e+03x elapsed=0:00:51.05
# frame=    1 fps=0.0 q=6.9 size=  537601KiB time=14:49:02.52 bitrate=  82.6kbits/s speed=1.03e+03x elapsed=0:00:51.58
# frame=    1 fps=0.0 q=6.9 size=  540161KiB time=14:53:24.07 bitrate=  82.5kbits/s speed=1.03e+03x elapsed=0:00:52.09
# frame=    1 fps=0.0 q=6.9 size=  543233KiB time=14:58:09.40 bitrate=  82.6kbits/s speed=1.02e+03x elapsed=0:00:52.61
# frame=    1 fps=0.0 q=6.9 size=  545793KiB time=15:02:30.95 bitrate=  82.6kbits/s speed=1.02e+03x elapsed=0:00:53.12
# frame=    1 fps=0.0 q=6.9 size=  548609KiB time=15:07:16.28 bitrate=  82.6kbits/s speed=1.01e+03x elapsed=0:00:53.64
# frame=    1 fps=0.0 q=6.9 size=  551425KiB time=15:11:37.83 bitrate=  82.6kbits/s speed=1.01e+03x elapsed=0:00:54.15
# frame=    1 fps=0.0 q=6.9 size=  554241KiB time=15:16:23.15 bitrate=  82.6kbits/s speed=1.01e+03x elapsed=0:00:54.67
# frame=    1 fps=0.0 q=6.9 size=  556801KiB time=15:20:44.70 bitrate=  82.6kbits/s speed=1e+03x elapsed=0:00:55.18
# frame=    1 fps=0.0 q=6.9 size=  559617KiB time=15:25:30.03 bitrate=  82.6kbits/s speed= 997x elapsed=0:00:55.70
# frame=    1 fps=0.0 q=6.9 size=  562433KiB time=15:29:51.58 bitrate=  82.6kbits/s speed= 992x elapsed=0:00:56.21
# frame=    1 fps=0.0 q=6.9 size=  564993KiB time=15:34:13.13 bitrate=  82.6kbits/s speed= 988x elapsed=0:00:56.74
# frame=    1 fps=0.0 q=6.9 size=  567553KiB time=15:38:34.68 bitrate=  82.6kbits/s speed= 984x elapsed=0:00:57.24
# [out#0/ipod @ 0000015078702640] video:20KiB audio:569776KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.670625%
# frame=    1 fps=0.0 q=6.9 Lsize=  579315KiB time=00:00:00.04 bitrate=118643671.6kbits/s speed=0.000693x elapsed=0:00:57.72
#
#
# Return code: 0

# %%
#Inspect any .m4b fole for stats

FFPROBE_BIN = r"D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffprobe.exe"
FILE = Path(r"./The Black Prism.m4b")

result = subprocess.run([
    FFPROBE_BIN,
    "-v", "error",
    "-show_entries", "format=duration,bit_rate",
    "-show_entries", "stream=index,codec_name,codec_type,channels,sample_rate",
    "-of", "json",
    str(FILE)
], text=True, capture_output=True)

print(result.stdout)
