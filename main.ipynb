# %% [markdown]
# # Harry potter

# %%
import os, json, subprocess, re, warnings
from pathlib import Path

warnings.filterwarnings("ignore")

# Adjust if notebook is elsewhere, but this matches your current layout
FFMPEG_DIR = Path("./") / "ffmpeg-2025-12-10-git-4f947880bd-essentials_build" / "bin"
FFMPEG_BIN = str((FFMPEG_DIR / "ffmpeg.exe").resolve())
FFPROBE_BIN = str((FFMPEG_DIR / "ffprobe.exe").resolve())

print("FFMPEG_BIN =", FFMPEG_BIN)
print("FFPROBE_BIN =", FFPROBE_BIN)

# Folder with your 50 MP3s
MP3_FOLDER = Path(r"D:/Downloads/Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook").resolve()
print("MP3_FOLDER =", MP3_FOLDER)

# Final output name (base)
DEFAULT_OUTPUT_NAME = "Oh_God_Not_Again_Harry_Potter_FanFic.m4b"

METADATA = {
    "title": "Oh God Not Again! Harry Potter FanFic",
    "artist": "Sarah1281",
    "author": "Sarah1281",
    "album": "Oh God Not Again! Harry Potter FanFic Audiobook",
    "album_artist": "Patronus Pages",
    "genre": "Audiobook",
    "date": "2008",
    "comment": (
        "Patronus Pages YT audiobook: "
        "https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD "
        "based on Harry Potter FanFic: "
        "https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again"
    ),
}

def get_duration(file_path: Path) -> float:
    """Get audio duration in seconds using ffprobe."""
    cmd = [
        FFPROBE_BIN, "-v", "quiet", "-print_format", "json",
        "-show_format", str(file_path)
    ]
    result = subprocess.run(cmd, capture_output=True, text=True, check=True)
    data = json.loads(result.stdout)
    return float(data["format"]["duration"])

def parse_chapter_number(filename: str) -> int:
    """Extract chapter number from 'Chapter X' pattern in filename."""
    match = re.search(r"Chapter\s+(\d+)", filename, re.IGNORECASE)
    return int(match.group(1)) if match else float("inf")
# Out:
# FFMPEG_BIN = ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe
# FFPROBE_BIN = ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffprobe.exe
# MP3_FOLDER = D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook

# %%
#Recode mp3 and create intermediate files

folder = MP3_FOLDER
print("Using MP3 folder:", folder)

mp3_files = list(folder.glob("*.mp3"))
if not mp3_files:
    raise SystemExit("No MP3 files found in folder")

# Sort by chapter number in filename
mp3_files.sort(key=lambda f: parse_chapter_number(f.name))

print(f"Found {len(mp3_files)} MP3 files (sorted by chapter):")
for i, mp3 in enumerate(mp3_files, 1):
    chap_num = parse_chapter_number(mp3.name)
    print(f"  {i:02d}. Chapter {chap_num if chap_num != float('inf') else '?'} -> {mp3.name}")

# 1a. Create concat list
concat_file = "concat.txt"
with open(concat_file, "w", encoding="utf-8") as f:
    for mp3 in mp3_files:
        f.write(f"file '{mp3.as_posix()}'\n")

print("Wrote concat list to:", concat_file)

# 1b. Create FFmetadata with chapters
ffmeta_file = "chapters.ffmetadata"
current_time = 0.0

with open(ffmeta_file, "w", encoding="utf-8") as f:
    f.write(";FFMETADATA1\n")
    for i, mp3 in enumerate(mp3_files, 1):
        duration = get_duration(mp3)
        start_ms = int(current_time * 1000)
        end_ms = int((current_time + duration) * 1000)

        chap_num = parse_chapter_number(mp3.name)
        if chap_num == float("inf"):
            chap_num = i
        chapter_title = f"Chapter {chap_num}"

        f.write("[CHAPTER]\n")
        f.write("TIMEBASE=1/1000\n")
        f.write(f"START={start_ms}\n")
        f.write(f"END={end_ms}\n")
        f.write(f"title={chapter_title}\n\n")

        current_time += duration
        print(f"  -> {chapter_title}: {duration/60:.1f} min")

print("Wrote chapter metadata to:", ffmeta_file)

# 1c. Concatenate MP3s to temporary M4A (AAC 80 kb/s mono)
temp_m4a = "temp_combined.m4a"
print("\n[Step 1] Concatenating MP3 files into AAC M4A (80 kb/s mono)...")
cmd = [
    FFMPEG_BIN, "-y",
    "-f", "concat", "-safe", "0",
    "-i", str(concat_file),
    "-ac", "1",          # mono
    "-c:a", "aac",
    "-b:a", "80k",       # target bitrate
    str(temp_m4a),
]
print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True)

print("Created:", temp_m4a)
print(f"Total duration ~ {current_time/3600:.2f} hours")
# Out:
# Using MP3 folder: D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook
# Found 50 MP3 files (sorted by chapter):
#   01. Chapter 1 -> Harry Potter - Oh God Not Again!  Chapter 1 _ FanFiction AudioBook.mp3
#   02. Chapter 2 -> Harry Potter - Oh God Not Again!  Chapter 2 _ FanFiction AudioBook.mp3
#   03. Chapter 3 -> Harry Potter - Oh God Not Again!  Chapter 3 _ FanFiction AudioBook.mp3
#   04. Chapter 4 -> Harry Potter - Oh God Not Again!  Chapter 4 _ FanFiction AudioBook.mp3
#   05. Chapter 5 -> Harry Potter - Oh God Not Again!  Chapter 5 _ FanFiction AudioBook.mp3
#   06. Chapter 6 -> Harry Potter - Oh God Not Again!  Chapter 6 _ FanFiction AudioBook.mp3
#   07. Chapter 7 -> Harry Potter - Oh God Not Again!  Chapter 7 _ FanFiction AudioBook.mp3
#   08. Chapter 8 -> Harry Potter - Oh God Not Again!  Chapter 8 _ FanFiction AudioBook.mp3
#   09. Chapter 9 -> Harry Potter - Oh God Not Again!  Chapter 9 _ FanFiction AudioBook.mp3
# ...

# %%
#Combine into one m4b with chapters

from pathlib import Path
import subprocess

AUDIO_IN   = "temp_combined.m4a"
FFMETA_IN  = "chapters.ffmetadata"
OUTPUT_M4B = "_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b"

print("Audio in:  ", AUDIO_IN)
print("Meta in:   ", FFMETA_IN)
print("Output m4b:", OUTPUT_M4B)

cmd = [
    FFMPEG_BIN, "-y",
    "-i", str(AUDIO_IN),      # 0: audio
    "-i", str(FFMETA_IN),     # 1: chapters
    "-map_metadata", "1",     # take chapters/metadata from ffmetadata
    "-c", "copy",
    "-metadata", f"title={METADATA['title']}",
    "-metadata", f"artist={METADATA['artist']}",
    "-metadata", f"author={METADATA['author']}",
    "-metadata", f"album={METADATA['album']}",
    "-metadata", f"album_artist={METADATA['album_artist']}",
    "-metadata", f"genre={METADATA['genre']}",
    "-metadata", f"date={METADATA['date']}",
    "-metadata", f"comment={METADATA['comment']}",
    str(OUTPUT_M4B),
]

print("Running:", " ".join(cmd))
result = subprocess.run(cmd, text=True, capture_output=True)
print("\n=== FFmpeg stdout ===\n", result.stdout)
print("\n=== FFmpeg stderr ===\n", result.stderr)
print("\nReturn code:", result.returncode)
# Out:
# Audio in:   temp_combined.m4a
# Meta in:    chapters.ffmetadata
# Output m4b: _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
# Running: D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe -y -i temp_combined.m4a -i chapters.ffmetadata -map_metadata 1 -c copy -metadata title=Oh God Not Again! Harry Potter FanFic -metadata artist=Sarah1281 -metadata author=Sarah1281 -metadata album=Oh God Not Again! Harry Potter FanFic Audiobook -metadata album_artist=Patronus Pages -metadata genre=Audiobook -metadata date=2008 -metadata comment=Patronus Pages YT audiobook: https://www.youtube.com/playlist?list=PLba8WLPdVZSrCgji3KUyDuHpYI3mVruZD based on Harry Potter FanFic: https://www.fanfiction.net/s/4536005/2/Oh-God-Not-Again _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
#
# === FFmpeg stdout ===
#
#
# === FFmpeg stderr ===
#  ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
# ...

# %%
#Add embeded cover

import subprocess
from pathlib import Path

folder = MP3_FOLDER

INPUT_M4B  = "_Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b"
COVER_IMG  = folder / "cover_thumbnail.jpg"    # or .png
OUTPUT_M4B = folder / "Oh_God_Not_Again_Harry_Potter_FanFic.m4b"

print("Input m4b: ", INPUT_M4B)
print("Cover:     ", COVER_IMG)
print("Output m4b:", OUTPUT_M4B)

if not COVER_IMG.exists():
    raise SystemExit(f"Cover image not found: {COVER_IMG}")

cmd = [
    FFMPEG_BIN, "-y",
    "-i", str(INPUT_M4B),      # 0: audio+chapters
    "-i", str(COVER_IMG),      # 1: cover
    "-map", "0:a",             # audio
    "-map", "0:t?",            # existing chapters/metadata
    "-map", "1:v",             # cover image
    "-c", "copy",
    "-c:v", "mjpeg" if COVER_IMG.suffix.lower() in [".jpg", ".jpeg"] else "png",
    "-disposition:v:0", "attached_pic",
    str(OUTPUT_M4B),
]

print("Running:", " ".join(cmd))
result = subprocess.run(cmd, text=True, capture_output=True)
print("\n=== FFmpeg stdout ===\n", result.stdout)
print("\n=== FFmpeg stderr ===\n", result.stderr)
print("\nReturn code:", result.returncode)
# Out:
# Input m4b:  _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b
# Cover:      D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\cover_thumbnail.jpg
# Output m4b: D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\Oh_God_Not_Again_Harry_Potter_FanFic.m4b
# Running: D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffmpeg.exe -y -i _Oh_God_Not_Again_Harry_Potter_FanFic_no_cover.m4b -i D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\cover_thumbnail.jpg -map 0:a -map 0:t? -map 1:v -c copy -c:v mjpeg -disposition:v:0 attached_pic D:\Downloads\Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook\Oh_God_Not_Again_Harry_Potter_FanFic.m4b
#
# === FFmpeg stdout ===
#
#
# === FFmpeg stderr ===
#  ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
# ...

# %%
#Inspect any .m4b fole for stats

FFPROBE_BIN = r"D:\projects\mp3tom4b_audiobook\ffmpeg-2025-12-10-git-4f947880bd-essentials_build\bin\ffprobe.exe"
FILE = Path(r"./The Black Prism.m4b")

result = subprocess.run([
    FFPROBE_BIN,
    "-v", "error",
    "-show_entries", "format=duration,bit_rate",
    "-show_entries", "stream=index,codec_name,codec_type,channels,sample_rate",
    "-of", "json",
    str(FILE)
], text=True, capture_output=True)

print(result.stdout)

# %% [markdown]
# # ADHD Twój mózg jest ok

# %%
import os, json, subprocess, re
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# FFmpeg paths (adjust if needed)
FFMPEG_DIR = Path("./") / "ffmpeg" / "bin"
FFMPEG_BIN = str((FFMPEG_DIR / "ffmpeg.exe").resolve())
FFPROBE_BIN = str((FFMPEG_DIR / "ffprobe.exe").resolve())

# Your audiobook folder
AUDIOBOOK_FOLDER = Path("./Tamara Rosier - ADHD Twoj mozg jest OK").resolve()
COVER_PATH = AUDIOBOOK_FOLDER / "cover.jpeg"  # Put your cover here (optional)

print("FFMPEG_BIN =", FFMPEG_BIN)
print("AUDIOBOOK_FOLDER =", AUDIOBOOK_FOLDER)
print("Cover file =", COVER_PATH)

def get_duration(file_path: Path) -> float:
    cmd = [FFPROBE_BIN, "-v", "quiet", "-print_format", "json", "-show_format", str(file_path)]
    result = subprocess.run(cmd, capture_output=True, text=True, check=True)
    return float(json.loads(result.stdout)["format"]["duration"])

def parse_chapter_number(filename: str) -> int:
    match = re.search(r'Chapter\s+(\d+)|(\d+).*Chapter|(\d+)', filename, re.IGNORECASE)
    return int(match.group(1) or match.group(2) or match.group(3) or len(filename)) if match else float('inf')

def probe_metadata(file_path: Path) -> dict:
    """Extract full metadata from MP3 using ffprobe"""
    cmd = [FFPROBE_BIN, "-v", "quiet", "-print_format", "json", "-show_format", "-show_streams", str(file_path)]
    result = subprocess.run(cmd, capture_output=True, text=True, check=True)
    return json.loads(result.stdout)
# Out:
# FFMPEG_BIN = D:\projects\mp3tom4b_audiobook\ffmpeg\bin\ffmpeg.exe
# AUDIOBOOK_FOLDER = D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK
# Cover file = D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK\cover.jpeg

# %%
folder = AUDIOBOOK_FOLDER
mp3_files = sorted(folder.glob("*.mp3"), key=lambda f: parse_chapter_number(f.name))

print(f"Found {len(mp3_files)} MP3 files:")
total_duration = 0
for i, mp3 in enumerate(mp3_files, 1):
    info = probe_metadata(mp3)
    duration = float(info["format"]["duration"])
    total_duration += duration
    
    # Safely convert metadata to numbers or show "N/A"
    bitrate = info["streams"][0].get("bit_rate")
    bitrate = f"{int(float(bitrate)):,}" if bitrate and str(bitrate) != "N/A" else "N/A"
    
    channels = info["streams"][0].get("channels")
    channels = str(channels) if channels and str(channels) != "N/A" else "N/A"
    
    sample_rate = info["streams"][0].get("sample_rate")
    sample_rate = str(sample_rate) if sample_rate and str(sample_rate) != "N/A" else "N/A"
    
    chap_num = parse_chapter_number(mp3.name)
    print(f"  {i:02d}. {mp3.name} | Ch {chap_num} | {duration:.1f}s | {bitrate}b/s | {channels}ch | {sample_rate}Hz")

print(f"\nTotal: ~{total_duration/3600:.1f} hours")

# 1a. Create concat list (preserves original order)
concat_file = folder / "concat.txt"
with open(concat_file, "w", encoding="utf-8") as f:
    for mp3 in mp3_files:
        f.write(f"file '{mp3.as_posix()}'\n")
print("✓ Created:", concat_file)

# 1b. Create chapters.ffmetadata (timing only, metadata preserved in Step 2)
ffmeta_file = folder / "chapters.ffmetadata"
current_time = 0.0
with open(ffmeta_file, "w", encoding="utf-8") as f:
    f.write(";FFMETADATA1\n")
    for i, mp3 in enumerate(mp3_files, 1):
        duration = get_duration(mp3)
        start_ms = int(current_time * 1000)
        end_ms = int((current_time + duration) * 1000)
        chap_num = parse_chapter_number(mp3.name)
        title = f"Chapter {chap_num}"
        
        f.write("[CHAPTER]\nTIMEBASE=1/1000\n")
        f.write(f"START={start_ms}\nEND={end_ms}\n")
        f.write(f"title={title}\n\n")
        current_time += duration

print("✓ Created:", ffmeta_file)
# Out:
# Found 28 MP3 files:
#   01. 01-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 1 | 277.2s | 128,000b/s | 1ch | 44100Hz
#   02. 02-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 2 | 850.2s | 128,000b/s | 1ch | 44100Hz
#   03. 03-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 3 | 1547.1s | 128,000b/s | 1ch | 44100Hz
#   04. 04-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 4 | 1342.1s | 128,000b/s | 1ch | 44100Hz
#   05. 05-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 5 | 1108.3s | 128,000b/s | 1ch | 44100Hz
#   06. 06-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 6 | 1008.5s | 128,000b/s | 1ch | 44100Hz
#   07. 07-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 7 | 1794.2s | 128,000b/s | 1ch | 44100Hz
#   08. 08-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 8 | 1294.3s | 128,000b/s | 1ch | 44100Hz
#   09. 09-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 | Ch 9 | 1536.8s | 128,000b/s | 1ch | 44100Hz
# ...

# %%
def has_cover_art(file_path: Path) -> bool:
    """Check if MP3 has embedded cover art using ffprobe"""
    cmd = [FFPROBE_BIN, "-v", "quiet", "-print_format", "json", "-show_streams", str(file_path)]
    result = subprocess.run(cmd, capture_output=True, text=True)
    data = json.loads(result.stdout)
    
    # Look for video streams (covers are typically video/mjpeg/png in MP3)
    for stream in data.get("streams", []):
        if stream.get("codec_type") == "video":
            return True
    return False

folder = AUDIOBOOK_FOLDER
mp3_files = list(folder.glob("*.mp3"))

print("Cover art check:")
has_cover = False
for mp3 in mp3_files:
    cover = has_cover_art(mp3)
    if cover:
        has_cover = True
        print(f"✓ {mp3.name} HAS cover art")
    else:
        print(f"✗ {mp3.name} NO cover art")

print(f"\nSummary: {'HAS cover art (skip external cover)' if has_cover else 'NO cover art (will add external)'}")
# Out:
# Cover art check:
# ✗ 01-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 02-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 03-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 04-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 05-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 06-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 07-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 08-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 09-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 10-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 11-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 12-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 13-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 14-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 15-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ✗ 16-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3 NO cover art
# ...

# %%
from pathlib import Path
ffmpeg_dir = Path.cwd() / "ffmpeg" / "bin"
print("FFmpeg files:", [f.name for f in ffmpeg_dir.glob("*.exe")])
# Out:
# FFmpeg files: ['ffmpeg.exe', 'ffplay.exe', 'ffprobe.exe']

# %% [markdown]
# #FSDFDSFSFDs

# %%
#check ffmpeg install

import subprocess
import os
import sys

print("=== Starting FFmpeg Debug ===")
print("Python executable:", sys.executable)
print("Current PATH preview:", os.environ['PATH'][:200] + "...")

# Test 1: Direct subprocess ffmpeg
print("\n1. Testing direct ffmpeg...")
try:
    result = subprocess.run(['ffmpeg', '-version'], capture_output=True, text=True, timeout=5)
    if result.returncode == 0:
        print("✅ FFmpeg in PATH - Version:", result.stdout.splitlines()[0])
    else:
        print("❌ FFmpeg failed:", result.stderr[:100])
except FileNotFoundError:
    print("❌ FFmpeg NOT in PATH")
except Exception as e:
    print("❌ Error:", str(e))
# Out:
# === Starting FFmpeg Debug ===
# Python executable: c:\Users\rrkar\anaconda3\python.exe
# Current PATH preview: c:\Users\rrkar\anaconda3;C:\Users\rrkar\anaconda3;C:\Users\rrkar\anaconda3\Library\mingw-w64\bin;C:\Users\rrkar\anaconda3\Library\usr\bin;C:\Users\rrkar\anaconda3\Library\bin;C:\Users\rrkar\anaconda3\...
#
# 1. Testing direct ffmpeg...
# ✅ FFmpeg in PATH - Version: ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers

# %%
import ffmpeg
import json

def extract_mp3_metadata(file_path):
    try:
        probe = ffmpeg.probe(file_path)
        return json.dumps(probe, indent=2)
    except ffmpeg.Error as e:
        return str(e.stderr.decode())

# Usage
metadata = extract_mp3_metadata(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/01-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3')
print(metadata)
# Out:
# {
#   "streams": [
#     {
#       "index": 0,
#       "codec_name": "mp3",
#       "codec_long_name": "MP3 (MPEG audio layer 3)",
#       "codec_type": "audio",
#       "codec_tag_string": "[0][0][0][0]",
#       "codec_tag": "0x0000",
#       "sample_fmt": "fltp",
#       "sample_rate": "44100",
#       "channels": 1,
#       "channel_layout": "mono",
#       "bits_per_sample": 0,
#       "initial_padding": 0,
#       "r_frame_rate": "0/0",
#       "avg_frame_rate": "0/0",
#       "time_base": "1/14112000",
#       "start_pts": 0,
#       "start_time": "0.000000",
#       "duration_ts": 3912334146,
#       "duration": "277.234562",
#       "bit_rate": "128000",
#       "disposition": {
#         "default": 0,
#         "dub": 0,
#         "original": 0,
#         "comment": 0,
#         "lyrics": 0,
#         "karaoke": 0,
#         "forced": 0,
#         "hearing_impaired": 0,
#         "visual_impaired": 0,
#         "clean_effects": 0,
#         "attached_pic": 0,
# ...

# %%
import ffmpeg
import json
import os
from pathlib import Path
from collections import defaultdict

def validate_mp3_directory(input_dir):
    input_dir = Path(input_dir)
    mp3_files = sorted(input_dir.glob("*.mp3"))
    
    if not mp3_files:
        print("❌ No MP3 files found!")
        return False
    
    print(f"✅ Found {len(mp3_files)} MP3 files")
    
    # Required tags to check
    REQUIRED_TAGS = {'album', 'artist', 'album_artist', 'comment', 'disc', 'genre', 'title', 'track', 'date'}
    
    # Track consistency
    audio_params = defaultdict(list)
    metadata_consistency = defaultdict(set)
    issues = []
    
    # Analyze each file
    for i, mp3_file in enumerate(mp3_files, 1):
        print(f"Analyzing {i}/{len(mp3_files)}: {mp3_file.name}")
        
        try:
            probe = ffmpeg.probe(str(mp3_file))
            audio_stream = next(s for s in probe['streams'] if s['codec_type'] == 'audio')
            # FIX: Check FORMAT tags, not stream tags!
            tags = probe['format'].get('tags', {})
            
            # Audio encoding parameters
            params = {
                'codec_name': audio_stream.get('codec_name'),
                'sample_rate': audio_stream.get('sample_rate'),
                'channels': audio_stream.get('channels'),
                'bit_rate': audio_stream.get('bit_rate'),
            }
            
            # Track unique values
            for key, value in params.items():
                if value:
                    audio_params[key].append(str(value))
            
            # Check required metadata (FIXED)
            missing_tags = [tag for tag in REQUIRED_TAGS if tag not in tags or not tags[tag].strip()]
            if missing_tags:
                issues.append(f"  ❌ Missing tags in {mp3_file.name}: {missing_tags}")
            
            # Track metadata values for consistency
            for tag in REQUIRED_TAGS:
                if tag in tags and tags[tag] and tags[tag].strip():
                    metadata_consistency[tag].add(tags[tag].strip())
            
        except Exception as e:
            issues.append(f"❌ Failed to probe {mp3_file.name}: {str(e)}")
    
    # Report encoding consistency
    print("\n=== AUDIO ENCODING CONSISTENCY ===")
    consistent = True
    for param, values in audio_params.items():
        unique_values = set(values)
        if len(unique_values) > 1:
            print(f"❌ {param} varies: {unique_values}")
            consistent = False
        else:
            print(f"✅ {param}: {list(unique_values)[0]}")
    
    # Report metadata consistency  
    print("\n=== METADATA CONSISTENCY ===")
    for tag, values in metadata_consistency.items():
        if len(values) > 1:
            print(f"⚠️  {tag} has {len(values)} variations: {values}")
        else:
            print(f"✅ {tag}: {list(values)[0] if values else 'N/A'}")
    
    # Summary
    print("\n=== VALIDATION SUMMARY ===")
    if issues:
        print("❌ ISSUES FOUND:")
        for issue in issues:
            print(issue)
    
    total_issues = len(issues)
    print(f"\n📊 {total_issues} files have missing tags, {len(mp3_files) - total_issues} files OK")
    
    if consistent:
        print("🎉 AUDIO ENCODING is consistent!")
    if total_issues == 0:
        print("✅ ALL METADATA PERFECT - READY FOR CONVERSION!")
        return True
    else:
        print("⚠️  Some metadata missing but audio is consistent - conversion will still work")
        return True  # Allow conversion even with missing tags

# Run fixed version
if validate_mp3_directory(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/'):
    print("\n✅ Ready for M4B conversion!")
# Out:
# ✅ Found 28 MP3 files
# Analyzing 1/28: 01-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 2/28: 02-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 3/28: 03-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 4/28: 04-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 5/28: 05-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 6/28: 06-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 7/28: 07-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 8/28: 08-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 9/28: 09-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 10/28: 10-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 11/28: 11-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 12/28: 12-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 13/28: 13-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 14/28: 14-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# Analyzing 15/28: 15-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3
# ...

# %%
import subprocess
from pathlib import Path
import ffmpeg

# Configuration
input_dir = Path(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/')
temp_audio = input_dir / 'temp_audio.m4a'

mp3_files = sorted(input_dir.glob("*.mp3"))
print(f"PHASE 1: Processing {len(mp3_files)} MP3 files")

# Create concat list
concat_list = input_dir / 'concat_list.txt'
with open(concat_list, 'w', encoding='utf-8') as f:
    for mp3_file in mp3_files:
        f.write(f"file '{mp3_file.absolute()}'\n")

print("✅ Concat list created")

# Concatenate MP3s → M4A (lossless)
cmd = [
    'ffmpeg',
    '-f', 'concat',
    '-safe', '0',
    '-i', str(concat_list),
    '-c', 'copy',
    '-y',
    str(temp_audio)
]

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print("✅ PHASE 1 COMPLETE")
    print(f"Temp audio created: {temp_audio}")
    print(f"Size: {temp_audio.stat().st_size / (1024**2):.1f} MB")
else:
    print("❌ PHASE 1 FAILED")
    print("STDERR:", result.stderr)
# Out:
# PHASE 1: Processing 28 MP3 files
# ✅ Concat list created
# ❌ PHASE 1 FAILED
# STDERR: ffmpeg version 2025-12-10-git-4f947880bd-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
# ...

# %%
# Create concat file
concat_list = input_dir / 'concat_list.txt'
with open(concat_list, 'w', encoding='utf-8') as f:
    for mp3_file in mp3_files:
        f.write(f"file '{mp3_file.absolute()}'\n")

# Concatenate (lossless)
print("🔗 Concatenating...")
(
    ffmpeg
    .input(str(concat_list), format='concat', safe=0)
    .output(str(input_dir / 'temp_concat.mp3'), c='copy')
    .overwrite_output()
    .run(quiet=True)
)
print("✅ temp_concat.mp3 created")
# Out:
# 🔗 Concatenating...
# ✅ temp_concat.mp3 created

# %%
import subprocess

print("🎧 Converting to M4B (direct FFmpeg)...")

cmd = [
    'ffmpeg', '-i', str(input_dir / 'temp_concat.mp3'),
    '-af', 'loudnorm=I=-16:TP=-1.5:LRA=11,aresample=44100',
    '-c:a', 'aac', '-b:a', '128k', '-ar', '44100', '-ac', '1',
    '-f', 'mp4', '-movflags', '+faststart'
]

# Add metadata properly
for key, value in keep_tags.items():
    if value:
        cmd.extend(['-metadata', f'{key}={value}'])

cmd.extend(['-y', str(output_m4b)])  # -y = overwrite

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print(f"✅ M4B created: {output_m4b}")
    print(f"Size: {os.path.getsize(output_m4b)/(1024**2):.1f} MB")
else:
    print("FFmpeg stderr:", result.stderr)
# Out:
# 🎧 Converting to M4B (direct FFmpeg)...
# ✅ M4B created: D:\projects\mp3tom4b_audiobook\ADHD_Twoj_mozg_jest_OK.m4b
# Size: 470.3 MB

# %%
print("📖 Adding chapters (using temp file)...")

# Step 1: Copy to temp with chapters
temp_m4b = output_m4b.with_suffix('.temp.m4b')
cmd = [
    'ffmpeg', 
    '-i', str(output_m4b),           # Audio
    '-i', str(chapters_path),        # Chapters  
    '-map', '0',                     # All audio streams
    '-map_chapters', '1',            # Chapters from input 1
    '-c', 'copy',
    '-movflags', '+faststart',
    '-y', str(temp_m4b)
]

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print("✅ Temp file with chapters created")
    
    # Step 2: Replace original
    os.replace(temp_m4b, output_m4b)
    print("✅ Chapters embedded in final file!")
else:
    print("Error:", result.stderr)
# Out:
# 📖 Adding chapters (using temp file)...
# ✅ Temp file with chapters created
# ✅ Chapters embedded in final file!

# %%
print("🔧 Creating PERFECT M4B in one command...")

# ONE COMMAND with embedded chapters (no separate step)
cmd = [
    'ffmpeg',
    '-f', 'concat', '-safe', '0', '-i', str(concat_list),  # All MP3s
    '-c:a', 'aac', '-b:a', '128k', '-ar', '44100', '-ac', '1',
    '-af', 'loudnorm=I=-16:TP=-1.5:LRA=11',
    '-f', 'mp4',
    
    # EMBED CHAPTERS DIRECTLY (no external file needed)
    '-metadata:s:ch:0', 'start=0', 
]

# Add ALL chapters as stream metadata
for i, (mp3_file, start_time) in enumerate(zip(mp3_files, chapter_times)):
    title = ffmpeg.probe(str(mp3_file))['format']['tags'].get('title', f'Chapter {i+1:02d}')
    cmd.extend([
        '-metadata:s:ch:0', f'title={i+1:02d}. {title}',
        '-metadata:s:ch:0', f'start={start_time}'
    ])

# Album metadata
for key, value in keep_tags.items():
    if value:
        cmd.extend(['-metadata', f'{key}={value}'])

cmd.extend(['-movflags', '+faststart', '-y', str(output_m4b)])

subprocess.run(cmd, capture_output=True, text=True, check=True)
print("🎉 PERFECT M4B with embedded chapters!")
# Out:
# 🔧 Creating PERFECT M4B in one command...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 16
#       4 cmd = [
#       5     'ffmpeg',
#       6     '-f', 'concat', '-safe', '0', '-i', str(concat_list),  # All MP3s
#    (...)
#      12     '-metadata:s:ch:0', 'start=0',
#      13 ]
#      15 # Add ALL chapters as stream metadata
# ---> 16 for i, (mp3_file, start_time) in enumerate(zip(mp3_files, chapter_times)):
#      17     title = ffmpeg.probe(str(mp3_file))['format']['tags'].get('title', f'Chapter {i+1:02d}')
#      18     cmd.extend([
#      19         '-metadata:s:ch:0', f'title={i+1:02d}. {title}',
#      20         '-metadata:s:ch:0', f'start={start_time}'
#      21     ])
#
# NameError: name 'chapter_times' is not defined

# %%
# Cleanup
for temp_file in ['concat_list.txt', 'chapters.txt', 'temp_concat.mp3']:
    (input_dir / temp_file).unlink(missing_ok=True)
    print(f"🗑️  Removed: {input_dir / temp_file}")

# Verify everything
probe = ffmpeg.probe(str(output_m4b))
format_info = probe['format']
print("\n🎉 FINAL VERIFICATION:")
print(f"📏 Duration: {float(format_info['duration'])/60:.1f} min")
print(f"🔊 Codec: {probe['streams'][0]['codec_name']}")
print(f"📻 Bitrate: {format_info.get('bit_rate', 'N/A')}")
print(f"🏷️  Tags: {len(format_info['tags'])} found")
if 'chapters' in probe:
    print(f"📖 Chapters: {len(probe['chapters'])}")
print("✅ Perfect M4B audiobook ready!")
# Out:
# 🗑️  Removed: D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK\concat_list.txt
# 🗑️  Removed: D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK\chapters.txt
# 🗑️  Removed: D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK\temp_concat.mp3
#
# 🎉 FINAL VERIFICATION:
# 📏 Duration: 471.8 min
# 🔊 Codec: aac
# 📻 Bitrate: 139367
# 🏷️  Tags: 12 found
# ✅ Perfect M4B audiobook ready!

# %%
probe = ffmpeg.probe(str(output_m4b))
if 'chapters' in probe:
    print("✅ CHAPTERS SUCCESSFULLY EMBEDDED!")
    print(f"📖 {len(probe['chapters'])} chapters found:")
    for i, chapter in enumerate(probe['chapters'][:5], 1):  # Show first 5
        start = chapter['start_time']
        title = chapter['tags']['title']
        print(f"  {i:02d}: {start} → {title}")
    if len(probe['chapters']) > 5:
        print(f"  ... and {len(probe['chapters'])-5} more")
else:
    print("⚠️ No chapters in ffprobe (normal - some players show them anyway)")

print(f"\n🎉 FINAL M4B SPECS:")
print(f"⏱️  Duration: {float(probe['format']['duration'])/60:.1f} min")
print(f"🔊 Codec: {probe['streams'][0]['codec_name']}")
print(f"📻 Bitrate: {format_info.get('bit_rate', 'N/A')}")
print(f"🏷️  Metadata: {list(probe['format']['tags'].keys())}")
print("✅ READY!")
# Out:
# ⚠️ No chapters in ffprobe (normal - some players show them anyway)
#
# 🎉 FINAL M4B SPECS:
# ⏱️  Duration: 471.8 min
# 🔊 Codec: aac
# 📻 Bitrate: 139367
# 🔊 Audio: AAC 137.0kbps mono 44.1kHz
# 🏷️  Metadata: ['major_brand', 'minor_version', 'compatible_brands', 'title', 'artist', 'album_artist', 'album', 'date', 'encoder', 'comment', 'genre', 'track']
# ✅ READY FOR BookPlayer/iTunes/VLC!

# %%
import ffmpeg
import json

def extract_mp3_metadata(file_path):
    try:
        probe = ffmpeg.probe(file_path)
        return json.dumps(probe, indent=2)
    except ffmpeg.Error as e:
        return str(e.stderr.decode())

# Usage
metadata = extract_mp3_metadata(r'D:/Downloads/Harry Potter - Oh God Not Again! FanFiction Patronus Pages AudioBook/Oh_God_Not_Again_Harry_Potter_FanFic.m4b')
print(metadata)
# Out:
# {
#   "streams": [
#     {
#       "index": 0,
#       "codec_name": "aac",
#       "codec_long_name": "AAC (Advanced Audio Coding)",
#       "profile": "LC",
#       "codec_type": "audio",
#       "codec_tag_string": "mp4a",
#       "codec_tag": "0x6134706d",
#       "sample_fmt": "fltp",
#       "sample_rate": "44100",
#       "channels": 1,
#       "channel_layout": "mono",
#       "bits_per_sample": 0,
#       "initial_padding": 0,
#       "id": "0x1",
#       "r_frame_rate": "0/0",
#       "avg_frame_rate": "0/0",
#       "time_base": "1/44100",
#       "start_pts": 0,
#       "start_time": "0.000000",
#       "duration_ts": 2491942912,
#       "duration": "56506.641995",
#       "bit_rate": "82602",
#       "nb_frames": "2433539",
#       "extradata_size": 5,
#       "disposition": {
#         "default": 1,
#         "dub": 0,
#         "original": 0,
#         "comment": 0,
#         "lyrics": 0,
#         "karaoke": 0,
#         "forced": 0,
#         "hearing_impaired": 0,
# ...

# %%
import ffmpeg
import json
import os
from pathlib import Path
from collections import defaultdict

def validate_mp3_directory(input_dir):
    input_dir = Path(input_dir)
    mp3_files = sorted(input_dir.glob("*.m4b"))
    
    if not mp3_files:
        print("❌ No MP3 files found!")
        return False
    
    print(f"✅ Found {len(mp3_files)} MP3 files")
    
    # Required tags to check
    REQUIRED_TAGS = {'album', 'artist', 'album_artist', 'comment', 'disc', 'genre', 'title', 'track', 'date'}
    
    # Track consistency
    audio_params = defaultdict(list)
    metadata_consistency = defaultdict(set)
    issues = []
    
    # Analyze each file
    for i, mp3_file in enumerate(mp3_files, 1):
        print(f"Analyzing {i}/{len(mp3_files)}: {mp3_file.name}")
        
        try:
            probe = ffmpeg.probe(str(mp3_file))
            audio_stream = next(s for s in probe['streams'] if s['codec_type'] == 'audio')
            # FIX: Check FORMAT tags, not stream tags!
            tags = probe['format'].get('tags', {})
            
            # Audio encoding parameters
            params = {
                'codec_name': audio_stream.get('codec_name'),
                'sample_rate': audio_stream.get('sample_rate'),
                'channels': audio_stream.get('channels'),
                'bit_rate': audio_stream.get('bit_rate'),
            }
            
            # Track unique values
            for key, value in params.items():
                if value:
                    audio_params[key].append(str(value))
            
            # Check required metadata (FIXED)
            missing_tags = [tag for tag in REQUIRED_TAGS if tag not in tags or not tags[tag].strip()]
            if missing_tags:
                issues.append(f"  ❌ Missing tags in {mp3_file.name}: {missing_tags}")
            
            # Track metadata values for consistency
            for tag in REQUIRED_TAGS:
                if tag in tags and tags[tag] and tags[tag].strip():
                    metadata_consistency[tag].add(tags[tag].strip())
            
        except Exception as e:
            issues.append(f"❌ Failed to probe {mp3_file.name}: {str(e)}")
    
    # Report encoding consistency
    print("\n=== AUDIO ENCODING CONSISTENCY ===")
    consistent = True
    for param, values in audio_params.items():
        unique_values = set(values)
        if len(unique_values) > 1:
            print(f"❌ {param} varies: {unique_values}")
            consistent = False
        else:
            print(f"✅ {param}: {list(unique_values)[0]}")
    
    # Report metadata consistency  
    print("\n=== METADATA CONSISTENCY ===")
    for tag, values in metadata_consistency.items():
        if len(values) > 1:
            print(f"⚠️  {tag} has {len(values)} variations: {values}")
        else:
            print(f"✅ {tag}: {list(values)[0] if values else 'N/A'}")
    
    # Summary
    print("\n=== VALIDATION SUMMARY ===")
    if issues:
        print("❌ ISSUES FOUND:")
        for issue in issues:
            print(issue)
    
    total_issues = len(issues)
    print(f"\n📊 {total_issues} files have missing tags, {len(mp3_files) - total_issues} files OK")
    
    if consistent:
        print("🎉 AUDIO ENCODING is consistent!")
    if total_issues == 0:
        print("✅ ALL METADATA PERFECT - READY FOR CONVERSION!")
        return True
    else:
        print("⚠️  Some metadata missing but audio is consistent - conversion will still work")
        return True  # Allow conversion even with missing tags

# Run fixed version
if validate_mp3_directory(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/'):
    print("\n✅ Ready for M4B conversion!")

# %% [markdown]
# # Adhd

# %%
import ffmpeg
import json

def extract_mp3_metadata(file_path):
    try:
        probe = ffmpeg.probe(file_path)
        return json.dumps(probe, indent=2)
    except ffmpeg.Error as e:
        return str(e.stderr.decode())

# Usage
metadata = extract_mp3_metadata(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/01-Tamara-Rosier-ADHD-Twoj-mozg-jest-OK.mp3')
print(metadata)
# Out:
# {
#   "streams": [
#     {
#       "index": 0,
#       "codec_name": "mp3",
#       "codec_long_name": "MP3 (MPEG audio layer 3)",
#       "codec_type": "audio",
#       "codec_tag_string": "[0][0][0][0]",
#       "codec_tag": "0x0000",
#       "sample_fmt": "fltp",
#       "sample_rate": "44100",
#       "channels": 1,
#       "channel_layout": "mono",
#       "bits_per_sample": 0,
#       "initial_padding": 0,
#       "r_frame_rate": "0/0",
#       "avg_frame_rate": "0/0",
#       "time_base": "1/14112000",
#       "start_pts": 0,
#       "start_time": "0.000000",
#       "duration_ts": 3912334146,
#       "duration": "277.234562",
#       "bit_rate": "128000",
#       "disposition": {
#         "default": 0,
#         "dub": 0,
#         "original": 0,
#         "comment": 0,
#         "lyrics": 0,
#         "karaoke": 0,
#         "forced": 0,
#         "hearing_impaired": 0,
#         "visual_impaired": 0,
#         "clean_effects": 0,
#         "attached_pic": 0,
# ...

# %%
import ffmpeg
import json
import os
from pathlib import Path
from collections import defaultdict

def validate_mp3_directory(input_dir):
    input_dir = Path(input_dir)
    mp3_files = sorted(input_dir.glob("*.mp3"))
    
    if not mp3_files:
        print("❌ No MP3 files found!")
        return False
    
    print(f"✅ Found {len(mp3_files)} MP3 files")
    
    # Required tags to check
    REQUIRED_TAGS = {'album', 'artist', 'album_artist', 'comment', 'disc', 'genre', 'title', 'track', 'date'}
    
    # Track consistency
    audio_params = defaultdict(list)
    metadata_consistency = defaultdict(set)
    issues = []
    
    # Analyze each file
    for i, mp3_file in enumerate(mp3_files, 1):
        print(f"Analyzing {i}/{len(mp3_files)}", end="\r", flush=True)
        
        try:
            probe = ffmpeg.probe(str(mp3_file))
            audio_stream = next(s for s in probe['streams'] if s['codec_type'] == 'audio')
            # FIX: Check FORMAT tags, not stream tags!
            tags = probe['format'].get('tags', {})
            
            # Audio encoding parameters
            params = {
                'codec_name': audio_stream.get('codec_name'),
                'sample_rate': audio_stream.get('sample_rate'),
                'channels': audio_stream.get('channels'),
                'bit_rate': audio_stream.get('bit_rate'),
            }
            
            # Track unique values
            for key, value in params.items():
                if value:
                    audio_params[key].append(str(value))
            
            # Check required metadata (FIXED)
            missing_tags = [tag for tag in REQUIRED_TAGS if tag not in tags or not tags[tag].strip()]
            if missing_tags:
                issues.append(f"  ❌ Missing tags in {mp3_file.name}: {missing_tags}")
            
            # Track metadata values for consistency
            for tag in REQUIRED_TAGS:
                if tag in tags and tags[tag] and tags[tag].strip():
                    metadata_consistency[tag].add(tags[tag].strip())
            
        except Exception as e:
            issues.append(f"❌ Failed to probe {mp3_file.name}: {str(e)}")
    
    # Report encoding consistency
    print("\n=== AUDIO ENCODING CONSISTENCY ===")
    consistent = True
    for param, values in audio_params.items():
        unique_values = set(values)
        if len(unique_values) > 1:
            print(f"❌ {param} varies: {unique_values}")
            consistent = False
        else:
            print(f"✅ {param}: {list(unique_values)[0]}")
    
    # Report metadata consistency  
    print("\n=== METADATA CONSISTENCY ===")
    for tag, values in metadata_consistency.items():
        if len(values) > 1:
            print(f"⚠️  {tag} has {len(values)} variations: {values}")
        else:
            print(f"✅ {tag}: {list(values)[0] if values else 'N/A'}")
    
    # Summary
    print("\n=== VALIDATION SUMMARY ===")
    if issues:
        print("❌ ISSUES FOUND:")
        for issue in issues:
            print(issue)
    
    total_issues = len(issues)
    print(f"\n📊 {total_issues} files have missing tags, {len(mp3_files) - total_issues} files OK")
    
    if consistent:
        print("🎉 AUDIO ENCODING is consistent!")
    if total_issues == 0:
        print("✅ ALL METADATA PERFECT - READY FOR CONVERSION!")
        return True
    else:
        print("⚠️  Some metadata missing but audio is consistent - conversion will still work")
        return True  # Allow conversion even with missing tags

# Run fixed version
if validate_mp3_directory(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/'):
    print("\n✅ Ready for M4B conversion!")
# Out:
# ✅ Found 28 MP3 files
# Analyzing 28/28
# === AUDIO ENCODING CONSISTENCY ===
# ✅ codec_name: mp3
# ✅ sample_rate: 44100
# ✅ channels: 1
# ✅ bit_rate: 128000
#
# === METADATA CONSISTENCY ===
# ✅ artist: Tamara Rosier
# ✅ album: ADHD. Twój mózg jest OK
# ...

# %%
print("PHASE 2: Generating chapters.ffmetadata...")

ffmeta_path = input_dir / 'chapters.ffmetadata'
total_ms = 0

with open(ffmeta_path, 'w', encoding='utf-8') as f:
    f.write(';FFMETADATA1\n\n')
    
    # Global metadata from first file
    probe0 = ffmpeg.probe(str(mp3_files[0]))
    tags = probe0['format']['tags']
    
    for key in ['album', 'artist', 'album_artist', 'genre', 'date', 'comment']:
        if tags.get(key):
            f.write(f"{key}={tags[key]}\n")
    
    f.write('\n')
    
    # Chapters with precise timestamps
    for i, mp3_file in enumerate(mp3_files, 1):
        probe = ffmpeg.probe(str(mp3_file))
        duration_ms = float(probe['format']['duration']) * 1000
        title = probe['format']['tags'].get('title', f'Chapter {i:02d}')
        
        f.write('[CHAPTER]\n')
        f.write('TIMEBASE=1/1000\n')
        f.write(f'START={int(total_ms)}\n')
        f.write(f'END={int(total_ms + duration_ms)}\n')
        f.write(f'title={title}\n\n')
        
        print(f"Chapter {i:02d}: {total_ms/1000:.1f}s → {title}")
        total_ms += duration_ms

print(f"\n✅ chapters.ffmetadata created: {ffmeta_path}")
print(f"Total duration: {total_ms/1000/60:.1f} minutes")
print("Ready for PHASE 3")
# Out:
# PHASE 2: Generating chapters.ffmetadata...
# Chapter 01: 0.0s → 01. Przedmowa
# Chapter 02: 277.2s → 02. Wstęp. Precz z udawaniem
# Chapter 03: 1127.4s → 03. Rozdział 1. A potem mój mózg robi dzyń!
# Chapter 04: 2674.5s → 04. Rozdział 2. Elfy, brudne bobasy i Lucille Ball
# Chapter 05: 4016.7s → 05. Rozdział 3. Zaginiony kamerdyner - a
# Chapter 06: 5124.9s → 06. Rozdział 3. Zaginiony kamerdyner - b
# Chapter 07: 6133.4s → 07. Rozdział 4. Goniąc króliczka - a
# Chapter 08: 7927.7s → 08. Rozdział 4. Goniąc króliczka - b
# Chapter 09: 9221.9s → 09. Rozdział 5. Potwory u naszych drzwi
# Chapter 10: 10758.7s → 10. Rozdział 6. Podstępne sztuczki motywacyjne - a
# Chapter 11: 12123.0s → 11. Rozdział 6. Podstępne sztuczki motywacyjne - b
# Chapter 12: 13182.0s → 12. Rozdział 7. Rozwiązywanie zagadki zabójstwa motywacji
# Chapter 13: 15004.5s → 13. Rozdział 8. Plansza operacyjna
# Chapter 14: 16797.5s → 14. Rozdział 9. Przewidywalne wzorce - a
# ...

# %%
# Create concat list
concat_list = input_dir / 'concat_list.txt'
with open(concat_list, 'w', encoding='utf-8') as f:
    for mp3_file in mp3_files:
        f.write(f"file '{mp3_file.absolute()}'\n")

temp_audio = input_dir / 'temp_audio.m4a'

print("PHASE 3: Concat + transcode to M4A...")

cmd = [
    'ffmpeg',
    '-f', 'concat',
    '-safe', '0',
    '-i', str(concat_list),
    '-c:a', 'aac',
    '-b:a', '128k',
    '-ar', '44100',
    '-ac', '1',
    '-y',
    str(temp_audio)
]

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print("✅ PHASE 3 COMPLETE")
    print(f"temp_audio.m4a: {temp_audio.stat().st_size / (1024**2):.1f} MB")
else:
    print("❌ PHASE 3 FAILED")
    print("STDERR:", result.stderr)
# Out:
# PHASE 3: Concat + transcode to M4A...
# ✅ PHASE 3 COMPLETE
# temp_audio.m4a: 469.3 MB

# %%
output_m4b = input_dir.parent / 'ADHD_Twoj_mozg_jest_OK.m4b'

print("PHASE 4: Final M4B with chapters...")

cmd = [
    'ffmpeg', '-y',
    '-i', str(temp_audio),           # Audio
    '-i', str(ffmeta_path),          # Chapters + metadata
    '-map_metadata', '1',            # Copy ALL from ffmetadata
    '-c', 'copy',                    # No re-encode
    '-movflags', '+faststart',
    str(output_m4b)
]

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print("✅ PHASE 4 COMPLETE - M4B WITH CHAPTERS READY!")
    print(f"Final file: {output_m4b.stat().st_size / (1024**2):.1f} MB")
else:
    print("❌ PHASE 4 FAILED")
    print("STDERR:", result.stderr)

# Cleanup
# for temp in [temp_audio, concat_list, ffmeta_path]:
#     if temp.exists():
#         temp.unlink()
#         print(f"🗑️  Cleaned: {temp.name}")

# print("\n🎉 Test in VLC/BookPlayer - 28 chapters should appear!")
# Out:
# PHASE 4: Final M4B with chapters...
# ✅ PHASE 4 COMPLETE - M4B WITH CHAPTERS READY!
# Final file: 469.3 MB

# %%
import subprocess
from pathlib import Path
import ffmpeg

# Paths
input_dir = Path(r'D:/projects/mp3tom4b_audiobook/Tamara Rosier - ADHD Twoj mozg jest OK/')
output_m4b = input_dir.parent / 'ADHD_Twoj_mozg_jest_OK.m4b'
cover_image = input_dir / 'cover.jpeg'

print("PHASE 5: Adding cover image...")

# Verify cover exists
if not cover_image.exists():
    print(f"❌ Cover image not found: {cover_image}")
    print("Please place cover.jpg in input directory or update path")
    exit(1)

print(f"Cover: {cover_image} ({cover_image.stat().st_size / 1024:.1f} KB)")

# Create temp M4B
temp_m4b = output_m4b.with_suffix('.temp.m4b')

cmd = [
    'ffmpeg', '-y',
    '-i', str(output_m4b),           # Input 0: Existing M4B (audio + chapters)
    '-i', str(cover_image),          # Input 1: Cover image
    '-map', '0:a:0',                 # ONLY audio stream
    '-map', '1:v:0',                 # Cover video  
    '-c:v', 'mjpeg',                 # Embed as jpeg or jpg (MP4 compatible)
    '-c:a', 'copy',                  # Copy audio (no re-encode)
    '-disposition:v', 'attached_pic',# Mark as cover art
    '-metadata:s:v', 'title=Cover',
    '-metadata:s:v', 'comment=Cover (front)',
    '-movflags', '+faststart',
    str(temp_m4b)
]

#     "-i", str(INPUT_M4B),      # 0: audio+chapters
#     "-i", str(COVER_IMG),      # 1: cover
#     "-map", "0:a",             # audio
#     "-map", "0:t?",            # existing chapters/metadata
#     "-map", "1:v",             # cover image
#     "-c", "copy",
#     "-c:v", "mjpeg" if COVER_IMG.suffix.lower() in [".jpg", ".jpeg"] else "png",
#     "-disposition:v:0", "attached_pic",


# cmd = [
#     'ffmpeg', '-y',
#     '-i', str(output_m4b),           # Input 0: M4B
#     '-i', str(cover_image),          # Input 1: Cover
#     '-map', '0:a:0',                 # ONLY audio stream
#     '-map', '1:v:0',                 # Cover video  
#     '-c:a', 'copy',                  # Preserve audio + chapters
#     '-c:v', 'png',                   # Cover as PNG
#     '-disposition:v:0', 'attached_pic',  # Mark as cover art
#     '-movflags', '+faststart',
#     str(temp_m4b)

result = subprocess.run(cmd, capture_output=True, text=True)
if result.returncode == 0:
    print("✅ Temp M4B with cover created")
    
    # Replace original
    output_m4b.unlink()
    temp_m4b.rename(output_m4b)
    print("✅ Cover embedded in final M4B!")
    
    # Verify
    probe = ffmpeg.probe(str(output_m4b))
    video_streams = [s for s in probe['streams'] if s['codec_type'] == 'video']
    print(f"📺 Video streams (cover): {len(video_streams)}")
    if video_streams:
        print(f"    Cover codec: {video_streams[0]['codec_name']}")
    
else:
    print("❌ FAILED")
    print("STDERR:", result.stderr)
# Out:
# PHASE 5: Adding cover image...
# Cover: D:\projects\mp3tom4b_audiobook\Tamara Rosier - ADHD Twoj mozg jest OK\cover.jpeg (74.7 KB)
# ✅ Temp M4B with cover created
# ✅ Cover embedded in final M4B!
# 📺 Video streams (cover): 1
#     Cover codec: mjpeg

# %%
import ffmpeg
import json

def extract_mp3_metadata(file_path):
    try:
        probe = ffmpeg.probe(file_path)
        return json.dumps(probe, indent=2)
    except ffmpeg.Error as e:
        return str(e.stderr.decode())

# Usage
metadata = extract_mp3_metadata(r'D:/Downloads/Stephen Fry - Troy - The Siege of Troy Retold.m4b')
print(metadata)
# Out:
# {
#   "streams": [
#     {
#       "index": 0,
#       "codec_name": "aac",
#       "codec_long_name": "AAC (Advanced Audio Coding)",
#       "profile": "LC",
#       "codec_type": "audio",
#       "codec_tag_string": "mp4a",
#       "codec_tag": "0x6134706d",
#       "sample_fmt": "fltp",
#       "sample_rate": "44100",
#       "channels": 2,
#       "channel_layout": "stereo",
#       "bits_per_sample": 0,
#       "initial_padding": 0,
#       "id": "0x1",
#       "r_frame_rate": "0/0",
#       "avg_frame_rate": "0/0",
#       "time_base": "1/44100",
#       "start_pts": 0,
#       "start_time": "0.000000",
#       "duration_ts": 1746405376,
#       "duration": "39601.028934",
#       "bit_rate": "125588",
#       "nb_frames": "1705474",
#       "extradata_size": 2,
#       "disposition": {
#         "default": 1,
#         "dub": 0,
#         "original": 0,
#         "comment": 0,
#         "lyrics": 0,
#         "karaoke": 0,
#         "forced": 0,
# ...
